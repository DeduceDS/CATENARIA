# %%
from electra_package.prerelease_2 import *

# %%
file = "XIN803"
path = "./data/lineas_completas/" + file + ".json"

data,summary = main_pipeline(path, 10)
# Out:
# 163 ['G_13645875_13645996', 'G_13037116_13511437', 'G_13037116_13645737', 'G_13645871_13645951', 'G_13645681_13645990', 'G_13645862_13645986', 'G_13645821_13645862', 'G_13645946_13645982', 'G_13088932_13149467', 'G_13645720_13645976', 'G_13645666_13645811', 'G_13088936_13145989', 'G_13645800_13645927', 'G_13645843_13645881', 'G_13645790_13645962', 'G_13645645_13645918', 'G_13618881_13645911', 'G_13618881_13645690', 'G_13645910_13645997', 'G_13645910_13645956']
# Setting logger
#
#  NUMBER OF BAD IDS 20
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_13645821_13645987
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8011)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 1
# Extracting vano info...
#
# Reference G_13645776_13645990
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4417)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['partially incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 2
# Extracting vano info...
#
# Reference G_13645684_13645777
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5527)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 3
# Extracting vano info...
#
# Reference G_13615863_13645824
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 1867)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 4
# Extracting vano info...
#
# Reference G_13645732_13645823
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4302)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 5
# Extracting vano info...
#
# Reference G_13499432_13645947
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2091)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 6
# Extracting vano info...
#
# Reference G_13645686_13645952
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4449)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 7
# Extracting vano info...
#
# Reference G_13037116_13511437
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 1107)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 0
# Completeness value: ['incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 1
# Other geometry
# Unrecognized geometry: variances (0.33689042057152724, 0.4021642837337885, 0.3946505375243038)
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 0, 0)
# Kmeans clustering for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 8
# Extracting vano info...
#
# Reference G_13618881_13645690
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5188)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
#
# Processing Vano 9
# Extracting vano info...
#
# Reference G_13645790_13645962
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 9238)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# METRICS:
# Bad cases vs good cases: 4, 6
# Mean RMSE and mean RmaxSE: 0.1710741416381969, 0.6926622921384936
# Mean correlation R Pearson and Spearman: 0.9493920361559427, 0.9355722427939979
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
# 'flag'
#                    ids        flags line_numbers configs        completenesses
# 0  G_13645821_13645987     good_fit  3 confirmed       0                  full
# 0  G_13645776_13645990     good_fit  3 confirmed       0  partially incomplete
# 0  G_13645684_13645777     good_fit  3 confirmed       0                  full
# 0  G_13615863_13645824  bad_cluster            3       0                  full
# 0  G_13645732_13645823     good_fit  3 confirmed       0                  full
# 0  G_13499432_13645947  bad_cluster            3       0                  full
# 0  G_13645686_13645952     good_fit  3 confirmed       0                  full
# 0  G_13037116_13511437  bad_cluster            0       0            incomplete
# 0  G_13618881_13645690     good_fit  3 confirmed       0                  full
# 0  G_13645790_13645962  bad_cluster            3       0                  full
