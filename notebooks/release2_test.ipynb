# %%
from electra_package.prerelease_2 import *

# %%
summary
# Out:
#                    ids reconstruccion     flags line_numbers  \
# 0  G_13645821_13645987        Posible  good_fit            3
#
#   line_confirmation configs completenesses p_huecos  Error_polilinea  \
# 0              True       0           full   49.17%         2.585803
#
#    Error_catenaria
# 0         1.052012

# %%
file = "XIN803"
path = "./data/lineas_completas/" + file + ".json"

data,summary = main_pipeline(path, 200)
# Out:
# Setting logger
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_13645821_13645987
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8011)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4592538.413734218, 852230.9834043543, 638.524810699374)
#
# Processing Vano 1
# Extracting vano info...
#
# Reference G_13645776_13645990
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4417)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['partially incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-1677820.7050246708, -4358583.791369847, 653.6954388221893)
#
# Processing Vano 2
# Extracting vano info...
#
# Reference G_13645684_13645777
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5527)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4664383.854980014, -237245.13595899116, 692.2533654384422)
#
# Processing Vano 3
# Extracting vano info...
#
# Reference G_13615863_13645824
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 1867)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 4
# Extracting vano info...
#
# Reference G_13645732_13645823
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4302)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4540083.124446986, 1095928.166774344, 671.7359167094326)
#
# Processing Vano 5
# Extracting vano info...
#
# Reference G_13499432_13645947
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2091)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 6
# Extracting vano info...
#
# Reference G_13645686_13645952
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4449)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (162338.91336565942, 4666800.4761095, 696.8879388497136)
#
# Processing Vano 7
# Extracting vano info...
#
# Reference G_13037116_13511437
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 1107)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 0
# Completeness value: ['incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 1
# Other geometry
# Unrecognized geometry: variances (0.33689042057152724, 0.4021642837337885, 0.3946505375243038)
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 0, 0)
# Kmeans clustering for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 8
# Extracting vano info...
#
# Reference G_13618881_13645690
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5188)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-3580153.0602967874, 2996968.3002157887, 675.704735749355)
#
# Processing Vano 9
# Extracting vano info...
#
# Reference G_13645790_13645962
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 9238)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 10
# Extracting vano info...
#
# Reference G_13645744_13645920
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 7076)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (2086942.5844851907, 4178961.282642195, 730.7020644692129)
#
# Processing Vano 11
# Extracting vano info...
#
# Reference G_13645844_13645888
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 6675)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (2931016.7607523445, 3637088.817184833, 697.9760897810104)
#
# Processing Vano 12
# Extracting vano info...
#
# Reference G_13645647_13645791
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5333)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-3728860.329496954, 2812917.583513765, 704.2680501174372)
#
# Processing Vano 13
# Extracting vano info...
#
# Reference G_13645750_13645842
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5900)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (376558.16092195373, 4654641.005351241, 668.2717866219374)
#
# Processing Vano 14
# Extracting vano info...
#
# Reference G_13645707_13645750
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5082)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['partially incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (391817.23207223456, 4653661.975692202, 678.8327308376174)
#
# Processing Vano 15
# Extracting vano info...
#
# Reference G_13645718_13645899
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2186)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4359192.179712665, 1690074.4808123321, 723.9339599172307)
#
# Processing Vano 16
# Extracting vano info...
#
# Reference G_13645765_13645809
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2326)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 17
# Extracting vano info...
#
# Reference G_13645665_13645719
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3662)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (956491.4625201642, 4575892.106111776, 773.2911028777304)
#
# Processing Vano 18
# Extracting vano info...
#
# Reference G_13088932_13645854
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4657)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (960959.5552615547, 4575267.477463077, 731.1261246442015)
#
# Processing Vano 19
# Extracting vano info...
#
# Reference G_13145989_13645938
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3998)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4370163.983345854, -1656678.021730028, 748.3497856280045)
#
# Processing Vano 20
# Extracting vano info...
#
# Reference G_13645721_13645813
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2825)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4361943.175033607, -1677942.6773511048, 758.0625224624425)
#
# Processing Vano 21
# Extracting vano info...
#
# Reference G_13645767_13645812
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3310)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4672825.580264759, -78416.05870680574, 775.0209392563012)
#
# Processing Vano 22
# Extracting vano info...
#
# Reference G_13645817_13645977
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4084)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 23
# Extracting vano info...
#
# Reference G_13645668_13645817
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5360)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-432453.4632958717, 4652805.425373203, 721.0430407565507)
#
# Processing Vano 24
# Extracting vano info...
#
# Reference G_13645771_13645980
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5370)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4595787.889745466, 836294.5779318273, 642.4535217647324)
#
# Processing Vano 25
# Extracting vano info...
#
# Reference G_13645819_13645906
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3790)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-628313.0377783756, 4628195.903807502, 637.9368246750918)
#
# Processing Vano 26
# Extracting vano info...
#
# Reference G_13645819_13645981
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4274)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-633608.5635797373, 4627610.2564099245, 638.4339424501139)
#
# Processing Vano 27
# Extracting vano info...
#
# Reference G_13645981_13645982
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4517)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (563401.3064671117, 4636828.54684237, 638.9111569041994)
#
# Processing Vano 28
# Extracting vano info...
#
# Reference G_13645776_13645989
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4498)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (1664785.4398670706, 4363464.433587719, 650.8934325737863)
#
# Processing Vano 29
# Extracting vano info...
#
# Reference G_13645683_13645951
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8107)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4663469.9658561805, -254907.97129095052, 648.7637601301406)
#
# Processing Vano 30
# Extracting vano info...
#
# Reference G_13645681_13645867
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4909)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4505371.291587839, 1231180.635689038, 666.1083923358929)
#
# Processing Vano 31
# Extracting vano info...
#
# Reference G_13645733_13645868
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2658)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4563473.452050415, -988715.212883881, 632.1165446179795)
#
# Processing Vano 32
# Extracting vano info...
#
# Reference G_13645738_13645781
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 9000)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4072489.3293554625, 2286205.5583700766, 726.260597192527)
#
# Processing Vano 33
# Extracting vano info...
#
# Reference G_13645687_13645874
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5533)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4668653.220264405, -129723.36970131184, 710.9363700569548)
#
# Processing Vano 34
# Extracting vano info...
#
# Reference G_13645737_13645873
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2571)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (177236.1440516193, 4666620.13258198, 718.2801176017304)
#
# Processing Vano 35
# Extracting vano info...
#
# Reference G_13511437_13511438
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3682)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (2628159.0862495573, 3860495.1372454907, 713.0507597466145)
#
# Processing Vano 36
# Extracting vano info...
#
# Reference G_13645910_13645956
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 6759)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 37
# Extracting vano info...
#
# Reference G_13645695_13645696
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5483)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-754197.6175359831, 4611180.09353799, 769.1771532867774)
#
# Processing Vano 38
# Extracting vano info...
#
# Reference G_13597802_13645916
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4940)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-758894.9895427722, 4610752.96309467, 776.4288880987333)
#
# Processing Vano 39
# Extracting vano info...
#
# Reference G_13645947_13645992
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2950)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 40
# Extracting vano info...
#
# Reference G_13645661_13645713
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# SOLO HAY 1 APOYO
# UN APOYO LIDAR
# Bad backings
# Bad clustering
#
# Processing Vano 41
# Extracting vano info...
#
# Reference G_13645798_13645842
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3904)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (357279.86426626553, 4656037.232786052, 664.7611650635394)
#
# Processing Vano 42
# Extracting vano info...
#
# Reference G_13645720_13645855
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 2883)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (948047.5882615658, 4576907.10531067, 819.085201082303)
#
# Processing Vano 43
# Extracting vano info...
#
# Reference G_13645809_13645810
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4295)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (947577.2753762817, 4577457.789719119, 848.8139695271855)
#
# Processing Vano 44
# Extracting vano info...
#
# Reference G_13645722_13645939
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4481)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (443251.1937800621, 4652369.4382859375, 726.6779122829317)
#
# Processing Vano 45
# Extracting vano info...
#
# Reference G_13645816_13645900
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5782)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-3417493.4192176093, -3187111.9877794017, 704.923263626741)
#
# Processing Vano 46
# Extracting vano info...
#
# Reference G_13645772_13645944
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8203)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4594217.323353944, 844487.3037270319, 641.8975117211855)
#
# Processing Vano 47
# Extracting vano info...
#
# Reference G_13645821_13645862
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 439)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 0
# Completeness value: ['incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 2
# Other geometry
# Distribución vertical
# Kmeans clustering for (config, max_conds, md, max_var): (1, 4, 0, 2)
# Kmeans clustering for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 48
# Extracting vano info...
#
# Reference G_13645727_13645822
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4593)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4594684.327343077, 840283.8166892758, 639.6760193690144)
#
# Processing Vano 49
# Extracting vano info...
#
# Reference G_13645683_13645684
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 7479)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4663135.770133091, -260809.89821243376, 667.6615906956849)
#
# Processing Vano 50
# Extracting vano info...
#
# Reference G_13645947_13645993
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3003)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4566222.130944588, -976330.9894025872, 634.8816089966317)
#
# Processing Vano 51
# Extracting vano info...
#
# Reference G_13645909_13645950
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 6719)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-925602.173396049, 4577416.373970508, 646.815131330619)
#
# Processing Vano 52
# Extracting vano info...
#
# Reference G_13645688_13645781
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 5604)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4075247.1297987914, 2281096.353538269, 724.9721077184686)
#
# Processing Vano 53
# Extracting vano info...
#
# Reference G_13037123_13645874
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8467)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-4668460.289492863, -136295.42755574555, 680.522594440139)
#
# Processing Vano 54
# Extracting vano info...
#
# Reference G_13645954_13645956
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4894)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 55
# Extracting vano info...
#
# Reference G_13645954_13645996
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 3160)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 56
# Extracting vano info...
#
# Reference G_13645875_13645996
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 8066)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 2
# Other geometry
# Distribución vertical
# Kmeans clustering for (config, max_conds, md, max_var): (1, 4, 3, 2)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# Processing Vano 57
# Extracting vano info...
#
# Reference G_13645641_13645642
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 4614)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-2270353.4754418978, 4083079.9638014315, 793.1582789544433)
#
# Processing Vano 58
# Extracting vano info...
#
# Reference G_13645696_13645697
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 7842)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Conductor number confirmation for 3 lines
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# (-777214.2101121192, 4607161.536329541, 769.542492711695)
#
# Processing Vano 59
# Extracting vano info...
#
# Reference G_13645862_13645986
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 987)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 0
# Completeness value: ['incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 0, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 3
# Good clustering with n conductors: 3
# Fitting and evaluating
# Fitting with catenaria function
# Interquartile filtering prefit
# Evaluating fits
# Saving results
# Setting vano score with old puntuation function
# Vano G_13645862_13645986 failed preprocess: local variable 'p_hueco' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File ~/Projects/electra-ia/electra_package/prerelease_2.py:262, in process_vano(vano)
#     260 fit1, fit2, fit3 = stack_unrotate_fits(pols, mat)
# --> 262 response_vano = puntuate_and_save(response_vano, fit1, fit2, fit3, params, evaluaciones, vano_length)
#     264 logger.critical(f"{np.array(pols[0]).mean(), np.array(pols[1]).mean(), np.array(pols[2]).mean()}")
#
# File ~/Projects/electra-ia/electra_package/prerelease_2.py:104, in puntuate_and_save(response_vano, fit1, fit2, fit3, params, evaluaciones, vano_length)
#     102 response_vano['CONDUCTORES_CORREGIDOS_PARAMETROS_(a,h,k)'][str(2)]=params[2]
# --> 104 response_vano=puntuación_por_vano(response_vano, evaluaciones, vano_length)
#     106 return response_vano
#
# File ~/Projects/electra-ia/electra_package/puntuacion.py:846, in puntuación_por_vano(response_vano, evaluaciones, longitud)
#     845 response_vano["reconstruccion"] = "No posible (n_cond != 3)"
# --> 846 response_vano["huecos"] = f"{p_hueco:.2f}%"
#     847 response_vano["Error_polilinea"] = 0
#
# UnboundLocalError: local variable 'p_hueco' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 file = "XIN803"
#       2 path = "./data/lineas_completas/" + file + ".json"
# ----> 4 data,summary = main_pipeline(path, 200)
#
# File ~/Projects/electra-ia/electra_package/prerelease_2.py:353, in main_pipeline(pathdata0, n_vanos)
#     350 logger.critical(f"\nProcessing Vano {i}")
#     352 # vano = copy.copy(data[i])
# --> 353 data[i], metrics = process_vano(data[i])
#     355 if metrics != -1:
#     357         rmses.append(metrics[0])
#
# File ~/Projects/electra-ia/electra_package/prerelease_2.py:295, in process_vano(vano)
#     293 except Exception as e:
#     294     logger.error(f"Vano {vano['ID_VANO']} failed preprocess: {e}")
# --> 295     raise ValueError("a")
#
# ValueError: a

# %%
summary
# Out:
#                     ids        flags line_numbers configs  \
# 0   G_13645821_13645987     good_fit  3 confirmed       0
# 0   G_13645776_13645990     good_fit  3 confirmed       0
# 0   G_13645684_13645777     good_fit  3 confirmed       0
# 0   G_13615863_13645824  bad_cluster            3       0
# 0   G_13645732_13645823     good_fit  3 confirmed       0
# ..                  ...          ...          ...     ...
# 0   G_13645826_13645909     good_fit  3 confirmed       0
# 0   G_13645647_13645790  bad_cluster            3       0
# 0   G_13645975_13645976  bad_cluster            2       0
# 0   G_13645856_13645977     good_fit  3 confirmed       0
# 0   G_13645800_13645927  bad_cluster            0       0
#
#           completenesses
# 0                   full
# 0   partially incomplete
# 0                   full
# 0                   full
# 0                   full
# ..                   ...
# 0   partially incomplete
# 0                   full
# 0                   full
# 0                   full
# 0             incomplete
#
# [161 rows x 5 columns]

# %%
from deliverable.modules_fit import * 
from deliverable.puntuacion import *
import os
import json
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
path = "./data/feedback_release_1/"
use_cases = os.listdir(path)

use_case1 = os.listdir(path+use_cases[0])[1]
use_case2 = os.listdir(path+use_cases[1])[0]
use_case3 = os.listdir(path+use_cases[2])[0]
use_case4 = os.listdir(path+use_cases[3])[0]

print(use_case1, use_case2, use_case3, use_case4)

with open(path+use_cases[0]+"/"+use_case1, 'r') as archivo:
    caso1 = json.load(archivo)

with open(path+use_cases[1]+"/"+use_case2, 'r') as archivo:
    caso2 = json.load(archivo)
    
with open(path+use_cases[2]+"/"+use_case3, 'r') as archivo:
    caso3 = json.load(archivo)
    
with open(path+use_cases[3]+"/"+use_case4, 'r') as archivo:
    caso4 = json.load(archivo)
# Out:
# G_92050855_92050856_Correcto200C.json G_92049646_92049647_Codigo200.json G_92049630_92049646.json G_92050860_92050861_ErrorAPI500.json

# %%
path+use_cases[0]+"/"+use_case1
# Out:
# './data/feedback_release_1/Correcto-200-Correcto/G_92050855_92050856_Correcto200C.json'

# %%
resp1=fit_plot_vano_group_2(caso1,sublist=[],plot_filter=None,init=0,end=None,save=False,label='')
resp2=fit_plot_vano_group_2(caso2,sublist=[],plot_filter=None,init=0,end=None,save=False,label='')
resp3=fit_plot_vano_group_2(caso3,sublist=[],plot_filter=None,init=0,end=None,save=False,label='')
resp4=fit_plot_vano_group_2(caso4,sublist=[],plot_filter=None,init=0,end=None,save=False,label='')
# Out:
# Processing Vano 0
#
# Reference G_92050855_92050856
# Umbral de corte inferior detectado: 3659101.9175527478
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Number of lines: 6
# {'Reconstrucción': 'Posible', 'Flag': 'Tiene 3 o más conductores. Porcentaje de huecos: 10.76%', 'Error polilínea': 34.0394742663, 'Error nuestro ajuste': 25.6215085097, 'Continuidad': 'full', 'Conductores identificados': 6, 'Output': 'bad_line_number'}
#
# Processing Vano 0
#
# Reference G_92049646_92049647
# Umbral de corte inferior detectado: 4510915.7221354
# Umbral de corte superior detectado: 4511289.735973548
# Number of lines: 0
# {'Reconstrucción': 'Posible', 'Flag': 'Tiene 3 o más conductores. Porcentaje de huecos: 45.81%', 'Error polilínea': 49.8290533395, 'Error nuestro ajuste': 52.8666090134, 'Continuidad': 'partially incomplete', 'Conductores identificados': 0, 'Output': 'bad_line_number'}
#
# Processing Vano 0
#
# Reference G_92049630_92049646
# Umbral de corte inferior detectado: 4510157.199450153
# Umbral de corte superior detectado: 4510590.022991822
# Number of lines: 2
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# {'Reconstrucción': 'Posible', 'Flag': 'Tiene 3 o más conductores. Porcentaje de huecos: 1.51%', 'Error polilínea': 75.8235436158, 'Error nuestro ajuste': 111.6118600798, 'Continuidad': 'full', 'Conductores identificados': 2, 'Output': 'bad_line_number'}
#
# Processing Vano 0
#
# Reference G_92050860_92050861
# Umbral de corte superior detectado: 4693553.040238826
# Number of lines: 0
# {'Reconstrucción': 'No posible', 'Flag': 'No tiene conductores', 'Error polilínea': 0, 'Error nuestro ajuste': 0, 'Continuidad': 'incomplete', 'Conductores identificados': 0, 'Output': 'empty'}

# %%
from electra_package.prerelease_2 import *

resp1,sum1 = main_pipeline(path+use_cases[0]+"/"+use_case1, 1)
resp2,sum2 = main_pipeline(path+use_cases[1]+"/"+use_case2, 1)
resp3,sum3 = main_pipeline(path+use_cases[2]+"/"+use_case3, 1)
resp4,sum4 = main_pipeline(path+use_cases[3]+"/"+use_case4, 1)
# Out:
# Setting logger
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_92050855_92050856
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 1473)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 6
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 6, 0)
# Kmeans clustering for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# METRICS:
# Empty metrics, no good cases...
#                    ids        flags line_numbers configs completenesses
# 0  G_92050855_92050856  bad_cluster            6       0           full
# Setting logger
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_92049646_92049647
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 510)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 3
# Completeness value: ['partially incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 3, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# METRICS:
# Empty metrics, no good cases...
#                    ids        flags line_numbers configs        completenesses
# 0  G_92049646_92049647  bad_cluster            3       0  partially incomplete
# Setting logger
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_92049630_92049646
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 959)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 2
# Completeness value: ['full']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 0
# Distribución horizontal
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 2, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# Kmeans clustering 2 for 3 clusters
# Bad clustering, next vano
# Bad clustering
#
# METRICS:
# Empty metrics, no good cases...
#                    ids        flags line_numbers configs completenesses
# 0  G_92049630_92049646  bad_cluster            2       0           full
# Setting logger
#
# Processing Vano 0
# Extracting vano info...
#
# Reference G_92050860_92050861
# Downsampling LIDAR to 25%
# Only 2 backings
# Analyzing backings
# Redefining backings
# Rotating vano
# Cropping conductor with backings
# Shape 2: (3, 235)
# Scaling conductor
# Analyzing conductor configuration 1
# Number of lines from mode: 0
# Completeness value: ['incomplete']
# Analyzing conductor configuration 2
# Max var coordinate for conductors 1
# Other geometry
# Unrecognized geometry: variances (0.2744170350784992, 0.3116242463338221, 0.1361994708432752)
# Kmeans clustering for (config, max_conds, md, max_var): (0, 4, 0, 0)
# Kmeans clustering for 2 clusters
# Kmeans clustering for 3 clusters
# Kmeans clustering 2 for 2 clusters
# GOOD CENTROIDS
# GOOD CLUSTERS: found 2
# Bad clustering, next vano
# Bad clustering
#
# METRICS:
# Empty metrics, no good cases...
#                    ids        flags line_numbers configs completenesses
# 0  G_92050860_92050861  bad_cluster            0       0     incomplete
