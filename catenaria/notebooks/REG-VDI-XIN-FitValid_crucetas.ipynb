# %%
from modules_main import *
# from old_modules.modules_fit import *
import json
import plotly.graph_objects as go
import numpy as np
import os
import pandas as pd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# Carga de dataframes con clasificación de ajuste posible/no posible.

# %%
pth=os.getcwd()
pthreg=pth+'/../data/lineas_completas/REG.csv'
reg_posible=pd.read_csv(pthreg)
pthvdi=pth+'/../data/lineas_completas/VDI.csv'
vdi_posible=pd.read_csv(pthvdi)
pthxin=pth+'/../data/lineas_completas/XIN.csv'
xin_posible=pd.read_csv(pthxin)
reg=reg_posible.loc[reg_posible['Reconstrucción']=='Posible','Vano']
vdi=vdi_posible.loc[vdi_posible['Reconstrucción']=='Posible','Vano']
xin=xin_posible.loc[xin_posible['Reconstrucción']=='Posible','Vano']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 pth=os.getcwd()
#       2 pthreg=pth+'/../data/lineas_completas/REG.csv'
# ----> 3 reg_posible=pd.read_csv(pthreg)
#       4 pthvdi=pth+'/../data/lineas_completas/VDI.csv'
#       5 vdi_posible=pd.read_csv(pthvdi)
#
# File ~/Projects/electra-ia/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Projects/electra-ia/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Projects/electra-ia/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Projects/electra-ia/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Projects/electra-ia/.venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ubuntu-deduce/Projects/electra-ia/catenaria/notebooks/../data/lineas_completas/REG.csv'

# %% [markdown]
# Generación de ajustes

# %%
# from catenaria.notebooks.old_modules.modules_fit import *
import json
import os

pathdata2 = os.getcwd()+"/../data/lineas_completas/REG804.json"

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)

fulld=[data[i]['ID_VANO'] for i in range(len(data))]
data, rmses, maxes, correlations=fit_plot_vano_group_2(data,sublist=fulld,plot_filter='good_fit',init=0,end=None,save=True,label='REG')#len(fulld)
#'bad_line_number', "bad_backing", bad_cluster, bad_line_number, bad_line_orientation, bad_fit, good_fit,
# Out:
# Processing Vano 0
#
# Reference G_13578462_13689863
# First time 0.03566575050354004
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4587882.060554319
# Umbral de corte superior detectado: -4587770.487469982
# Analyzing conductor configuration
# Third time 0.6441419124603271
# Number of lines: 3
# Fourth time 0.002820253372192383
# Starting fit
# Prefit data shape (3, 3827)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.2749907970428467
# clustering time 2 0.0024328231811523438
# clustering time 3.278698205947876
# Fifth time 3.2859649658203125
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.5088244430868583, 0.9652111859492485
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8608704440421795, 0.8644368572090758
# RmeanSE and RmaxSE error for z coordinate: 0.9997334384984505, 1.2775474680255545
# Fit Pearson R and Fit Spearman R for z coordinate: 0.02308806337569954, -0.014730417088441293
# RmeanSE and RmaxSE error for z coordinate: 0.9114862585196136, 1.5103519810463695
# Fit Pearson R and Fit Spearman R for z coordinate: 0.41134120185785195, 0.7740740272385842
# Sixth time 0.029257535934448242
# Evaluating fit
# Seventh time 0.008856058120727539
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578462_13689863"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.24%"},"Error polil\u00ednea":{"0":4587825.6117955474},"Error nuestro ajuste":{"0":1.2377010541}}
# Eigth time 0.006659269332885742
#
# Processing Vano 1
#
# Reference G_13576896_13576897
# First time 0.029651880264282227
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2784357.7462366684
# Umbral de corte superior detectado: -2784247.5663992786
# Analyzing conductor configuration
# Third time 0.7756819725036621
# Number of lines: 7
# Setting vano score
# Vano score {"Vano":{"0":"G_13576896_13576897"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 50.00%"},"Error polil\u00ednea":{"0":0},"Error nuestro ajuste":{"0":0.0}}
# Eigth time 0.8218080997467041
#
# Processing Vano 2
#
# Reference G_13576773_13576897
# First time 0.05428361892700195
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2797900.2300038426
# Umbral de corte superior detectado: -2797801.6903558127
# Analyzing conductor configuration
# Third time 0.7593090534210205
# Number of lines: 6
# Fourth time 0.004792213439941406
# Starting fit
# Prefit data shape (3, 6240)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 17.54450011253357
# clustering time 2 0.0008416175842285156
# clustering time 17.54590344429016
# Fifth time 17.55391550064087
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.941132155570915, 1.321515196207661
# Fit Pearson R and Fit Spearman R for z coordinate: 0.3380388696529855, 0.36682459298211895
# RmeanSE and RmaxSE error for z coordinate: 0.8536961214812809, 2.0119204170494376
# Fit Pearson R and Fit Spearman R for z coordinate: 0.5207714779132258, 0.37931034482758613
# RmeanSE and RmaxSE error for z coordinate: 0.5072347005882293, 1.1424927347103937
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8618079600992249, 0.8255131964809383
# Sixth time 0.015411615371704102
# Evaluating fit
# Seventh time 0.006247043609619141
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576773_13576897"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.15%"},"Error polil\u00ednea":{"0":2797850.9713868336},"Error nuestro ajuste":{"0":0.807462985}}
# Eigth time 0.00402069091796875
#
# Processing Vano 3
#
# Reference G_13576773_13576774
# First time 0.020681142807006836
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2799930.1091222866
# Umbral de corte superior detectado: -2799804.903328614
# Analyzing conductor configuration
# Third time 0.683213472366333
# Number of lines: 6
# Fourth time 0.0025663375854492188
# Starting fit
# Prefit data shape (3, 7794)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 5.444536447525024
# clustering time 2 0.0021467208862304688
# clustering time 5.44779634475708
# Fifth time 5.451146125793457
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.9284617668011658, 1.2644571255821042
# Fit Pearson R and Fit Spearman R for z coordinate: 0.37143056160289767, 0.3763864828101783
# RmeanSE and RmaxSE error for z coordinate: 0.873358165589834, 1.2541165667318572
# Fit Pearson R and Fit Spearman R for z coordinate: 0.4870787466462625, 0.4741488104346335
# RmeanSE and RmaxSE error for z coordinate: 0.032773113240138305, 0.11946609169028855
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9994628201912268, 0.9002801120448181
# Sixth time 0.019887924194335938
# Evaluating fit
# Seventh time 0.00580596923828125
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576773_13576774"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.11%"},"Error polil\u00ednea":{"0":2799868.1495778938},"Error nuestro ajuste":{"0":2.0504888813}}
# Eigth time 0.004285335540771484
#
# Processing Vano 4
#
# Reference G_13576907_13576908
# First time 0.021952152252197266
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2802456.1083957753
# Umbral de corte superior detectado: -2802335.382156318
# Analyzing conductor configuration
# Third time 0.5814032554626465
# Number of lines: 6
# Fourth time 0.0041925907135009766
# Starting fit
# Prefit data shape (3, 8238)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 6.950805425643921
# clustering time 2 0.001931905746459961
# clustering time 6.953534364700317
# Fifth time 6.9574198722839355
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.6066143610638357, 0.8778761466947147
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7950045872895587, 0.7569163723817407
# RmeanSE and RmaxSE error for z coordinate: 0.5687982578669972, 1.3046973193520568
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8224770795022875, 0.805031890277444
# RmeanSE and RmaxSE error for z coordinate: 0.9113520154708478, 1.2217884446381022
# Fit Pearson R and Fit Spearman R for z coordinate: 0.4116279554861495, 0.4319432093677096
# Sixth time 0.018172740936279297
# Evaluating fit
# Seventh time 0.005203962326049805
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576907_13576908"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.10%"},"Error polil\u00ednea":{"0":2802395.0506597753},"Error nuestro ajuste":{"0":1.4180040684}}
# Eigth time 0.004201412200927734
#
# Processing Vano 5
#
# Reference G_13578307_13578514
# First time 0.006049394607543945
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2340533.210728575
# Analyzing conductor configuration
# Third time 0.07396245002746582
# Number of lines: 3
# Fourth time 0.0012869834899902344
# Starting fit
# Prefit data shape (3, 1364)
# Applying spectral clustering
# clustering time 1 0.18909239768981934
# clustering time 2 0.0010528564453125
# clustering time 0.19071602821350098
# Fifth time 0.19356846809387207
# Fitting catenaria to data
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# RmeanSE and RmaxSE error for z coordinate: 0.23834944782519257, 1.4778067289289105
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9712694477397916, 0.9410924526925681
# RmeanSE and RmaxSE error for z coordinate: 0.15376609134691338, 0.49428324700051085
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9881919606529819, 0.9895095371294482
# RmeanSE and RmaxSE error for z coordinate: 0.9779640680803822, 2.6400399183357504
# Fit Pearson R and Fit Spearman R for z coordinate: 0.20877560015269625, 0.18193848587952596
# Sixth time 0.01696014404296875
# Evaluating fit
# Seventh time 0.004698991775512695
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578307_13578514"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 4.45%"},"Error polil\u00ednea":{"0":2340583.6839426667},"Error nuestro ajuste":{"0":1.421030567}}
# Eigth time 0.0046885013580322266
#
# Processing Vano 6
#
# Reference G_13578498_13578512
# First time 0.01283717155456543
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -3832123.7057611994
# Analyzing conductor configuration
# Third time 0.10189461708068848
# Number of lines: 3
# Fourth time 0.0013642311096191406
# Starting fit
# Prefit data shape (3, 2243)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.3178675174713135
# clustering time 2 0.0016353130340576172
# clustering time 0.3206765651702881
# Fifth time 0.3241903781890869
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.10173392362461656, 0.19000865255385946
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9948116486244373, 0.9950504229353885
# RmeanSE and RmaxSE error for z coordinate: 0.06415549118701731, 0.24617771270944622
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9979399155538489, 0.9976387397200501
# RmeanSE and RmaxSE error for z coordinate: 0.03451418068707609, 0.11714506338555536
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9994042271887958, 0.9989791904415287
# Sixth time 0.017628192901611328
# Evaluating fit
# Seventh time 0.005342960357666016
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578498_13578512"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.08%"},"Error polil\u00ednea":{"0":3832086.4441522323},"Error nuestro ajuste":{"0":1.462142244}}
# Eigth time 0.0047190189361572266
#
# Processing Vano 7
#
# Reference G_13578435_13578450
# First time 0.013248920440673828
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -708907.28493114
# Analyzing conductor configuration
# Third time 0.2633380889892578
# Number of lines: 3
# Fourth time 0.0020751953125
# Starting fit
# Prefit data shape (3, 3854)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 1.3585116863250732
# clustering time 2 0.001613616943359375
# clustering time 1.360628366470337
# Fifth time 1.3650672435760498
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.16858781489344674, 0.37174170630807546
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9857303044518742, 0.9815941398542033
# RmeanSE and RmaxSE error for z coordinate: 0.3070068279693578, 0.6713358865978363
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9518444291258574, 0.9596765275830377
# RmeanSE and RmaxSE error for z coordinate: 0.4378664770252396, 1.4176362802732803
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8990415893390153, 0.844001189624034
# Sixth time 0.012187480926513672
# Evaluating fit
# Seventh time 0.0064144134521484375
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578435_13578450"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.16%"},"Error polil\u00ednea":{"0":708842.9457910033},"Error nuestro ajuste":{"0":1.709076012}}
# Eigth time 0.0044786930084228516
#
# Processing Vano 8
#
# Reference G_13578338_13578340
# First time 0.017164230346679688
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -710058.0912884551
# Analyzing conductor configuration
# Third time 0.5129480361938477
# Number of lines: 3
# Fourth time 0.004829883575439453
# Starting fit
# Prefit data shape (3, 6887)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.4488255977630615
# clustering time 2 0.0015101432800292969
# clustering time 3.450995445251465
# Fifth time 3.4568727016448975
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.11730124176873236, 0.44279795429927304
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9931577712244607, 0.9803915037343186
# RmeanSE and RmaxSE error for z coordinate: 0.11861464629767157, 0.44411357772429616
# Fit Pearson R and Fit Spearman R for z coordinate: 0.992940372758532, 0.9889009763776456
# RmeanSE and RmaxSE error for z coordinate: 0.14419574364959367, 0.387300381551424
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9896547236482539, 0.9978778657410947
# Sixth time 0.01710224151611328
# Evaluating fit
# Seventh time 0.0053369998931884766
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578338_13578340"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.07%"},"Error polil\u00ednea":{"0":709954.3354469998},"Error nuestro ajuste":{"0":1.7331432608}}
# Eigth time 0.004708290100097656
#
# Processing Vano 9
#
# Reference G_13578470_13578521
# First time 0.029819250106811523
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4694624.258775833
# Umbral de corte superior detectado: -4694405.728620398
# Analyzing conductor configuration
# Third time 0.6219239234924316
# Number of lines: 3
# Fourth time 0.002535581588745117
# Starting fit
# Prefit data shape (3, 9211)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.551985025405884
# clustering time 2 0.0021173954010009766
# clustering time 3.5548858642578125
# Fifth time 3.5594332218170166
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.19877969387727204, 0.5407645714110705
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9800487630940256, 0.9081215719230661
# RmeanSE and RmaxSE error for z coordinate: 0.09724164082014146, 0.2735482334002568
# Fit Pearson R and Fit Spearman R for z coordinate: 0.995297337016347, 0.9985672446575501
# RmeanSE and RmaxSE error for z coordinate: 0.02333620748177115, 0.0695823781379743
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9997276958034926, 0.9963828994943326
# Sixth time 0.01772451400756836
# Evaluating fit
# Seventh time 0.005738973617553711
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578470_13578521"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.00%"},"Error polil\u00ednea":{"0":4694515.4486455088},"Error nuestro ajuste":{"0":1.8166226274}}
# Eigth time 0.00469207763671875
#
# Processing Vano 10
#
# Reference G_13578475_13578503
# First time 0.013055086135864258
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 118832.53365239952
# Analyzing conductor configuration
# Third time 0.2544238567352295
# Number of lines: 3
# Fourth time 0.0020570755004882812
# Starting fit
# Prefit data shape (3, 3729)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 4.706021308898926
# clustering time 2 0.0007228851318359375
# clustering time 4.707144498825073
# Fifth time 4.720037460327148
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.08976665886989156, 0.12209493554109814
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9959628242527616, 0.9915065561136966
# RmeanSE and RmaxSE error for z coordinate: 0.006103940715513632, 0.0224458634623399
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9999813708067696, 0.9999466955178409
# RmeanSE and RmaxSE error for z coordinate: 0.5362599977865835, 1.2533756003218421
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8440528912451141, 0.8464285714285712
# Sixth time 0.017229795455932617
# Evaluating fit
# Seventh time 0.005430459976196289
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578475_13578503"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.54%"},"Error polil\u00ednea":{"0":118912.3211749018},"Error nuestro ajuste":{"0":0.7238987621}}
# Eigth time 0.003704547882080078
#
# Processing Vano 11
#
# Reference G_13578475_13578516
# First time 0.009814262390136719
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 113288.39228564287
# Umbral de corte superior detectado: 113375.34922208045
# Analyzing conductor configuration
# Third time 0.08974552154541016
# Number of lines: 2
# Setting vano score
# Vano score {"Vano":{"0":"G_13578475_13578516"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 50.00%"},"Error polil\u00ednea":{"0":0},"Error nuestro ajuste":{"0":0.0}}
# Eigth time 0.10750889778137207
#
# Processing Vano 12
#
# Reference G_13576793_13576873
# First time 0.017347335815429688
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2862823.0038110255
# Umbral de corte superior detectado: -2862728.3747259155
# Analyzing conductor configuration
# Third time 0.4089829921722412
# Number of lines: 6
# Fourth time 0.002613544464111328
# Starting fit
# Prefit data shape (3, 6746)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 2.921626091003418
# clustering time 2 0.001705169677734375
# clustering time 2.9239141941070557
# Fifth time 2.930760383605957
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.6081166071802694, 0.9296367495505558
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7938477466531886, 0.7896117457688532
# RmeanSE and RmaxSE error for z coordinate: 0.6116230102045734, 0.8404594645598991
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7911493539302897, 0.7882494302631488
# RmeanSE and RmaxSE error for z coordinate: 0.9849173522265355, 1.3209123641390021
# Fit Pearson R and Fit Spearman R for z coordinate: 0.1730262583999203, 0.3016464659604396
# Sixth time 0.017329692840576172
# Evaluating fit
# Seventh time 0.005043745040893555
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576793_13576873"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.01%"},"Error polil\u00ednea":{"0":2862775.5573018021},"Error nuestro ajuste":{"0":1.7575669668}}
# Eigth time 0.0038232803344726562
#
# Processing Vano 13
#
# Reference G_13576748_13576812
# First time 0.023107051849365234
# Redefining backings
# Distance between mean points: 97.69968420113601
# Second time 0.10232663154602051
# Rotating vano
# Cropping conductor
# index -1 is out of bounds for axis 0 with size 0
#
# Processing Vano 14
#
# Reference G_13576762_13576801
# First time 0.023487091064453125
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 2873350.8379759043
# Analyzing conductor configuration
# Third time 0.4546031951904297
# Number of lines: 6
# Fourth time 0.0034110546112060547
# Starting fit
# Prefit data shape (3, 7115)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.939901351928711
# clustering time 2 0.00170135498046875
# clustering time 3.942492961883545
# Fifth time 3.946770191192627
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.4763167718253474, 0.6576882303710387
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8792737538308019, 0.8768450353890211
# RmeanSE and RmaxSE error for z coordinate: 0.38747737262202087, 0.5335677108040262
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9218792152667492, 0.9104579894287624
# RmeanSE and RmaxSE error for z coordinate: 0.9388976687587427, 1.2834378305819982
# Fit Pearson R and Fit Spearman R for z coordinate: 0.3441969506188167, 0.3488930926232583
# Sixth time 0.020160436630249023
# Evaluating fit
# Seventh time 0.005644083023071289
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576762_13576801"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.08%"},"Error polil\u00ednea":{"0":2873417.3619421166},"Error nuestro ajuste":{"0":0.4203921561}}
# Eigth time 0.004485368728637695
#
# Processing Vano 15
#
# Reference G_13576736_13576740
# First time 0.020079612731933594
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2868098.0357494564
# Umbral de corte superior detectado: -2868031.043597402
# Analyzing conductor configuration
# Third time 0.2671847343444824
# Number of lines: 6
# Fourth time 0.0014450550079345703
# Starting fit
# Prefit data shape (3, 3539)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.066164255142212
# clustering time 2 0.0013926029205322266
# clustering time 3.0683133602142334
# Fifth time 3.070625066757202
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.4452579951308543, 0.6408749799967403
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8954023218290252, 0.8990011333474532
# RmeanSE and RmaxSE error for z coordinate: 0.4625275959689068, 0.6068688070583961
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8866048859913082, 0.8919446691324122
# RmeanSE and RmaxSE error for z coordinate: 0.1788115176735216, 0.37178750422302365
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9838833473269637, 0.9259740259740258
# Sixth time 0.016924381256103516
# Evaluating fit
# Seventh time 0.006116151809692383
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576736_13576740"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.20%"},"Error polil\u00ednea":{"0":2868070.2049135547},"Error nuestro ajuste":{"0":1.8324155221}}
# Eigth time 0.004524946212768555
#
# Processing Vano 16
#
# Reference G_13578445_13578497
# First time 0.020274639129638672
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4186489.863163928
# Analyzing conductor configuration
# Third time 0.11871528625488281
# Number of lines: 3
# Fourth time 0.0011708736419677734
# Starting fit
# Prefit data shape (3, 2084)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.44412922859191895
# clustering time 2 0.0020971298217773438
# clustering time 0.44704174995422363
# Fifth time 0.44954657554626465
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.08185740669322183, 0.1890765341691817
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9966442209328141, 0.9909837549757866
# RmeanSE and RmaxSE error for z coordinate: 0.038359156062879055, 0.132834482414396
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9992641312843429, 0.9984875604731462
# RmeanSE and RmaxSE error for z coordinate: 0.6186847635278487, 1.2474599082787217
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7856500009060852, 0.7348164627363738
# Sixth time 0.015204429626464844
# Evaluating fit
# Seventh time 0.004856109619140625
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578445_13578497"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.54%"},"Error polil\u00ednea":{"0":4186526.0940322089},"Error nuestro ajuste":{"0":1.6767468695}}
# Eigth time 0.004808902740478516
#
# Processing Vano 17
#
# Reference G_13578298_13578310
# First time 0.014439821243286133
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4471360.717461009
# Analyzing conductor configuration
# Third time 0.10057234764099121
# Number of lines: 3
# Fourth time 0.0013608932495117188
# Starting fit
# Prefit data shape (3, 2147)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.3735535144805908
# clustering time 2 0.0018401145935058594
# clustering time 0.3767201900482178
# Fifth time 0.37917351722717285
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.03371938109461067, 0.09080705127969668
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9994313399822323, 0.9930162752431339
# RmeanSE and RmaxSE error for z coordinate: 0.09063712348735528, 0.19023912341170024
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9958839853285733, 0.9952083862644329
# RmeanSE and RmaxSE error for z coordinate: 0.332123256216629, 0.7671967245799693
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9432359952838202, 0.8995073891625613
# Sixth time 0.017454147338867188
# Evaluating fit
# Seventh time 0.004311561584472656
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578298_13578310"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.13%"},"Error polil\u00ednea":{"0":4471405.1211231546},"Error nuestro ajuste":{"0":1.6000646316}}
# Eigth time 0.006467580795288086
#
# Processing Vano 18
#
# Reference G_13578331_13578405
# First time 0.01761460304260254
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 4692103.806625351
# Umbral de corte superior detectado: 4692193.802346572
# Analyzing conductor configuration
# Third time 0.13823723793029785
# Number of lines: 3
# Fourth time 0.0021104812622070312
# Starting fit
# Prefit data shape (3, 2636)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.8245909214019775
# clustering time 2 0.0012392997741699219
# clustering time 0.8265347480773926
# Fifth time 0.8307528495788574
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.7685634075598908, 2.820237716816167
# Fit Pearson R and Fit Spearman R for z coordinate: 0.6398319924649213, 0.6743716528457054
# RmeanSE and RmaxSE error for z coordinate: 0.9260013610795553, 1.5617492799630057
# Fit Pearson R and Fit Spearman R for z coordinate: 0.3775201711028776, 0.38181818181818183
# RmeanSE and RmaxSE error for z coordinate: 0.45915456514607966, 1.623257074762196
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8884833216846484, 0.89072466376238
# Sixth time 0.01676201820373535
# Evaluating fit
# Seventh time 0.00423431396484375
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578331_13578405"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 1.01%"},"Error polil\u00ednea":{"0":4692147.3726388803},"Error nuestro ajuste":{"0":0.4692840023}}
# Eigth time 0.0044100284576416016
#
# Processing Vano 19
#
# Reference G_13576769_13576858
# First time 0.012180328369140625
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2166325.9738128544
# Analyzing conductor configuration
# Third time 0.07277274131774902
# Number of lines: 0
# Setting vano score
# Vano score {"Vano":{"0":"G_13576769_13576858"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 50.00%"},"Error polil\u00ednea":{"0":0},"Error nuestro ajuste":{"0":0.0}}
# Eigth time 0.09476232528686523
#
# Processing Vano 20
#
# Reference G_13578278_13578317
# First time 0.03158760070800781
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -1042432.4659481401
# Analyzing conductor configuration
# Third time 0.2808494567871094
# Number of lines: 3
# Fourth time 0.0026009082794189453
# Starting fit
# Prefit data shape (3, 4081)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 2.6986165046691895
# clustering time 2 0.0022029876708984375
# clustering time 2.7018463611602783
# Fifth time 2.707691192626953
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.574906595349553, 1.2146571947311804
# Fit Pearson R and Fit Spearman R for z coordinate: 0.818223966853806, 0.7430653302080513
# RmeanSE and RmaxSE error for z coordinate: 0.3174000809134198, 1.241789151362573
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9482917213192092, 0.9495909309516439
# RmeanSE and RmaxSE error for z coordinate: 0.15926692524899774, 0.44025357865122905
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9872355577681724, 0.9848867090209746
# Sixth time 0.016139745712280273
# Evaluating fit
# Seventh time 0.005357503890991211
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578278_13578317"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.08%"},"Error polil\u00ednea":{"0":1042389.8999469811},"Error nuestro ajuste":{"0":0.8727797048}}
# Eigth time 0.004477262496948242
#
# Processing Vano 21
#
# Reference G_13578309_13578415
# First time 0.016275405883789062
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 1049618.9092660663
# Umbral de corte superior detectado: 1049752.7485602195
# Analyzing conductor configuration
# Third time 0.28414416313171387
# Number of lines: 3
# Fourth time 0.0015125274658203125
# Starting fit
# Prefit data shape (3, 3931)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 2.878504991531372
# clustering time 2 0.0017862319946289062
# clustering time 2.8813316822052
# Fifth time 2.885112762451172
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.3248587929689205, 2.229607361926386
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9457968522250418, 0.9089516997080153
# RmeanSE and RmaxSE error for z coordinate: 0.4483785847371514, 0.9264762073722872
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8938437496529823, 0.8530769230769231
# RmeanSE and RmaxSE error for z coordinate: 0.5112307702480989, 1.1285382930382029
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8594434825140191, 0.8644030145317873
# Sixth time 0.018573760986328125
# Evaluating fit
# Seventh time 0.0049746036529541016
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578309_13578415"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.16%"},"Error polil\u00ednea":{"0":1049685.3855917237},"Error nuestro ajuste":{"0":0.2061416099}}
# Eigth time 0.003973722457885742
#
# Processing Vano 22
#
# Reference G_13578299_13578463
# First time 0.014798641204833984
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -649480.4406086168
# Analyzing conductor configuration
# Third time 0.2508554458618164
# Number of lines: 3
# Fourth time 0.0008530616760253906
# Starting fit
# Prefit data shape (3, 3443)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 2.1708898544311523
# clustering time 2 0.002023458480834961
# clustering time 2.1737239360809326
# Fifth time 2.1755809783935547
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.11533595377595028, 0.38914645622108235
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9933265413583926, 0.9880269786692457
# RmeanSE and RmaxSE error for z coordinate: 0.4389359227883287, 0.8167893996688935
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8986387529034214, 0.8629455385672995
# RmeanSE and RmaxSE error for z coordinate: 0.3329954528627413, 0.7570605887165572
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9429284324731463, 0.9244993981836086
# Sixth time 0.026870012283325195
# Evaluating fit
# Seventh time 0.005457162857055664
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578299_13578463"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.17%"},"Error polil\u00ednea":{"0":649535.2086135993},"Error nuestro ajuste":{"0":0.9773852031}}
# Eigth time 0.005177736282348633
#
# Processing Vano 23
#
# Reference G_13578374_13578463
# First time 0.013697624206542969
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 644296.613117003
# Umbral de corte superior detectado: 644389.0192780996
# Analyzing conductor configuration
# Third time 0.16904115676879883
# Number of lines: 3
# Fourth time 0.0011849403381347656
# Starting fit
# Prefit data shape (3, 2748)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.8000392913818359
# clustering time 2 0.0013432502746582031
# clustering time 0.801964282989502
# Fifth time 0.8042483329772949
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.04125632792159986, 0.08811069012897765
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9991485959486619, 0.9986443114820018
# RmeanSE and RmaxSE error for z coordinate: 0.019706123271585014, 0.08692543712053147
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9998058155038373, 0.9995412386228616
# RmeanSE and RmaxSE error for z coordinate: 0.10522104397382588, 0.26882022643056214
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9944488583659705, 0.9978507055201906
# Sixth time 0.019700050354003906
# Evaluating fit
# Seventh time 0.00528407096862793
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578374_13578463"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 12.34%"},"Error polil\u00ednea":{"0":644353.8126427763},"Error nuestro ajuste":{"0":0.5522031057}}
# Eigth time 0.004640102386474609
#
# Processing Vano 24
#
# Reference G_13578285_13578315
# First time 0.005978584289550781
# Redefining backings
# Distance between mean points: 40.92277076644581
# Second time 0.07731246948242188
# Rotating vano
# Cropping conductor
# index -1 is out of bounds for axis 0 with size 0
#
# Processing Vano 25
#
# Reference G_13576890_13576891
# First time 0.030562877655029297
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2797774.1438695285
# Umbral de corte superior detectado: -2797632.206265988
# Analyzing conductor configuration
# Third time 0.7591495513916016
# Number of lines: 6
# Fourth time 0.003367900848388672
# Starting fit
# Prefit data shape (3, 10318)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 8.477785587310791
# clustering time 2 0.0017282962799072266
# clustering time 8.480007886886597
# Fifth time 8.484784603118896
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.5091113275294368, 0.7046991896643608
# Fit Pearson R and Fit Spearman R for z coordinate: 0.860700684658211, 0.7835021944343252
# RmeanSE and RmaxSE error for z coordinate: 0.4887549889249695, 0.9161838943041951
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8724227577676518, 0.835656744556189
# RmeanSE and RmaxSE error for z coordinate: 0.22218599084144638, 0.4343358251462133
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9750044204088473, 0.9591927047645324
# Sixth time 0.014558076858520508
# Evaluating fit
# Seventh time 0.008278846740722656
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576890_13576891"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: -0.06%"},"Error polil\u00ednea":{"0":2797703.5873429249},"Error nuestro ajuste":{"0":2.5758326343}}
# Eigth time 0.004822969436645508
#
# Processing Vano 26
#
# Reference G_13577128_13577129
# First time 0.02545452117919922
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2804831.459982425
# Umbral de corte superior detectado: -2804692.1152223186
# Analyzing conductor configuration
# Third time 0.788853645324707
# Number of lines: 6
# Fourth time 0.002991914749145508
# Starting fit
# Prefit data shape (3, 9507)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 26.001184940338135
# clustering time 2 0.0011744499206542969
# clustering time 26.003902673721313
# Fifth time 26.008079051971436
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.18064135392610794, 0.43432844202190335
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9835650683743381, 0.9263196480938415
# RmeanSE and RmaxSE error for z coordinate: 0.7588457038684534, 1.086898356716425
# Fit Pearson R and Fit Spearman R for z coordinate: 0.6512883386077335, 0.5723657475047591
# RmeanSE and RmaxSE error for z coordinate: 0.049212106226980405, 0.24546072458104984
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9987883502533751, 0.9979286143490591
# Sixth time 0.016789674758911133
# Evaluating fit
# Seventh time 0.007817506790161133
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13577128_13577129"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.17%"},"Error polil\u00ednea":{"0":2804762.7563323528},"Error nuestro ajuste":{"0":1.1876193074}}
# Eigth time 0.005291938781738281
#
# Processing Vano 27
#
# Reference G_13578282_13578382
# First time 0.010930061340332031
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -3866213.079726978
# Analyzing conductor configuration
# Third time 0.20468664169311523
# Number of lines: 3
# Fourth time 0.004918813705444336
# Starting fit
# Prefit data shape (3, 2809)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.3958108425140381
# clustering time 2 0.0018892288208007812
# clustering time 0.3983285427093506
# Fifth time 0.4017317295074463
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.07909976101009852, 0.5882942192839052
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9968687780441341, 0.9700240340134736
# RmeanSE and RmaxSE error for z coordinate: 0.9086538204309562, 2.785169595771435
# Fit Pearson R and Fit Spearman R for z coordinate: 0.41755027939169387, 0.48260828275120404
# RmeanSE and RmaxSE error for z coordinate: 0.047554936527400296, 0.13647413619805215
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9988686245608043, 0.9952899378341282
# Sixth time 0.016817092895507812
# Evaluating fit
# Seventh time 0.005319833755493164
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578282_13578382"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.14%"},"Error polil\u00ednea":{"0":3866260.1345208124},"Error nuestro ajuste":{"0":1.0192314683}}
# Eigth time 0.00595402717590332
#
# Processing Vano 28
#
# Reference G_13578407_13578444
# First time 0.013031721115112305
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -711215.2702545
# Analyzing conductor configuration
# Third time 0.20417141914367676
# Number of lines: 3
# Fourth time 0.0020813941955566406
# Starting fit
# Prefit data shape (3, 3063)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.7965240478515625
# clustering time 2 0.0016849040985107422
# clustering time 0.7989206314086914
# Fifth time 0.8072812557220459
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.6937236066878877, 2.0039744363774643
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7202413190261394, 0.6658761528326744
# RmeanSE and RmaxSE error for z coordinate: 0.05505054773137881, 0.16947148558763292
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9984861887559089, 0.9872682713985412
# RmeanSE and RmaxSE error for z coordinate: 0.07117482836140096, 0.20568842455330982
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9974643060981908, 0.9873266174813031
# Sixth time 0.015219926834106445
# Evaluating fit
# Seventh time 0.009664535522460938
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578407_13578444"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 3.27%"},"Error polil\u00ednea":{"0":711162.8667614353},"Error nuestro ajuste":{"0":1.7342675116}}
# Eigth time 0.006613254547119141
#
# Processing Vano 29
#
# Reference G_13578394_13578435
# First time 0.019826889038085938
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -713259.4252104687
# Analyzing conductor configuration
# Third time 0.34070444107055664
# Number of lines: 3
# Fourth time 0.002724885940551758
# Starting fit
# Prefit data shape (3, 5075)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 1.8993992805480957
# clustering time 2 0.0027573108673095703
# clustering time 1.902801752090454
# Fifth time 1.9070181846618652
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.16628397004786716, 0.5325038017857904
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9862039119404653, 0.9817370074594325
# RmeanSE and RmaxSE error for z coordinate: 0.23601748147527826, 0.8320173177057857
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9717488093374489, 0.9702402106704613
# RmeanSE and RmaxSE error for z coordinate: 0.027835989195359897, 0.09747718533920224
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9996125107355602, 0.9981137310315696
# Sixth time 0.016485214233398438
# Evaluating fit
# Seventh time 0.005764007568359375
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578394_13578435"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.04%"},"Error polil\u00ednea":{"0":713182.0787480458},"Error nuestro ajuste":{"0":1.1623972879}}
# Eigth time 0.004636049270629883
#
# Processing Vano 30
#
# Reference G_13578301_13578439
# First time 0.013413190841674805
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -706476.5071047008
# Analyzing conductor configuration
# Third time 0.27269792556762695
# Number of lines: 3
# Fourth time 0.002759695053100586
# Starting fit
# Prefit data shape (3, 4512)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 2.748283624649048
# clustering time 2 0.0016613006591796875
# clustering time 2.751030921936035
# Fifth time 2.756063938140869
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.23819141793785784, 0.5754186133326821
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9712993422714151, 0.9483969049718104
# RmeanSE and RmaxSE error for z coordinate: 0.6551601614533146, 1.8653697533773674
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7554900150534993, 0.7350877192982455
# RmeanSE and RmaxSE error for z coordinate: 0.17651253125327723, 0.4614015103870067
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9842983929354399, 0.9266345797852645
# Sixth time 0.015271902084350586
# Evaluating fit
# Seventh time 0.0061490535736083984
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578301_13578439"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 1.19%"},"Error polil\u00ednea":{"0":706415.915468913},"Error nuestro ajuste":{"0":0.9504880893}}
# Eigth time 0.004248857498168945
#
# Processing Vano 31
#
# Reference G_13578311_13578407
# First time 0.019898653030395508
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 704033.2676543483
# Umbral de corte superior detectado: 704149.5926292504
# Analyzing conductor configuration
# Third time 0.3961317539215088
# Number of lines: 3
# Fourth time 0.002476215362548828
# Starting fit
# Prefit data shape (3, 5747)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.528449773788452
# clustering time 2 0.0014951229095458984
# clustering time 3.531113862991333
# Fifth time 3.538135290145874
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.12382325025511597, 0.3148333496015616
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9923804466983113, 0.9962429821003352
# RmeanSE and RmaxSE error for z coordinate: 0.13935639714525846, 1.2286100161776952
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9902795516912034, 0.9933553403205148
# RmeanSE and RmaxSE error for z coordinate: 0.052183693639810895, 0.27445954582610166
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9986375028686816, 0.9981758361303877
# Sixth time 0.015367507934570312
# Evaluating fit
# Seventh time 0.005395650863647461
# Reconstructing X axis
# Setting vano score
# ...
# RmeanSE and RmaxSE error for z coordinate: 0.061316923699403336, 0.2075859571445653
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9981183491782087, 0.9959860897720534
# RmeanSE and RmaxSE error for z coordinate: 0.29351657375715134, 0.9523281061332889
# Fit Pearson R and Fit Spearman R for z coordinate: 0.955958696519161, 0.7776590092769089
# Sixth time 0.01806044578552246
# Evaluating fit
# Seventh time 0.0049059391021728516
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578452_13578480"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 1.16%"},"Error polil\u00ednea":{"0":4470428.4790773764},"Error nuestro ajuste":{"0":1.3460000137}}
# Eigth time 0.005486726760864258
#
# Processing Vano 71
#
# Reference G_13578337_13578377
# First time 0.016591787338256836
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4577182.069298104
# Umbral de corte superior detectado: -4577055.869135804
# Analyzing conductor configuration
# Third time 0.481708288192749
# Number of lines: 3
# Fourth time 0.003787517547607422
# Starting fit
# Prefit data shape (3, 3805)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 1.99171781539917
# clustering time 2 0.0012848377227783203
# clustering time 1.9935317039489746
# Fifth time 1.9969828128814697
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.12658102908891988, 0.5048027682062981
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9919623049058888, 0.9812176040644923
# RmeanSE and RmaxSE error for z coordinate: 0.40228424446478156, 0.7713771983887026
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9155909506772966, 0.9173334910495551
# RmeanSE and RmaxSE error for z coordinate: 0.8340768197698399, 1.8638745024918069
# Fit Pearson R and Fit Spearman R for z coordinate: 0.5516483107233114, 0.5207746332096957
# Sixth time 0.01555180549621582
# Evaluating fit
# Seventh time 0.004333019256591797
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578337_13578377"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.33%"},"Error polil\u00ednea":{"0":4577119.1367355213},"Error nuestro ajuste":{"0":2.2256964748}}
# Eigth time 0.003606081008911133
#
# Processing Vano 72
#
# Reference G_13578393_13578412
# First time 0.014714717864990234
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 118801.35054604214
# Analyzing conductor configuration
# Third time 0.3568546772003174
# Number of lines: 3
# Fourth time 0.003735065460205078
# Starting fit
# Prefit data shape (3, 4077)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 4.526954889297485
# clustering time 2 0.001657247543334961
# clustering time 4.52958083152771
# Fifth time 4.5350823402404785
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.6544247302400316, 1.0222266477749182
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7561507092721542, 0.7195242339965039
# RmeanSE and RmaxSE error for z coordinate: 0.5357238329237448, 1.387051415987613
# Fit Pearson R and Fit Spearman R for z coordinate: 0.844529714282791, 0.804796793196093
# RmeanSE and RmaxSE error for z coordinate: 0.806610764400251, 1.9538232922985328
# Fit Pearson R and Fit Spearman R for z coordinate: 0.5910829683409193, 0.6545454545454547
# Sixth time 0.019579172134399414
# Evaluating fit
# Seventh time 0.005115509033203125
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578393_13578412"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.03%"},"Error polil\u00ednea":{"0":118864.0230322909},"Error nuestro ajuste":{"0":1.0106274035}}
# Eigth time 0.0040435791015625
#
# Processing Vano 73
#
# Reference G_13578372_13578476
# First time 0.018818378448486328
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -701740.7578525239
# Analyzing conductor configuration
# Third time 0.48023533821105957
# Number of lines: 3
# Fourth time 0.0026972293853759766
# Starting fit
# Prefit data shape (3, 5174)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 3.13598895072937
# clustering time 2 0.006591081619262695
# clustering time 3.1437809467315674
# Fifth time 3.1542766094207764
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.07732527164644305, 0.2352562547360919
# Fit Pearson R and Fit Spearman R for z coordinate: 0.997022866892455, 0.9994032556907801
# RmeanSE and RmaxSE error for z coordinate: 0.13138103284615363, 0.43107518887249563
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9913319727308809, 0.9880964050105253
# RmeanSE and RmaxSE error for z coordinate: 0.125352191614431, 0.48045929639716123
# Fit Pearson R and Fit Spearman R for z coordinate: 0.992204156254584, 0.9833589797401372
# Sixth time 0.02465534210205078
# Evaluating fit
# Seventh time 0.005716085433959961
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578372_13578476"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.12%"},"Error polil\u00ednea":{"0":701828.9432939045},"Error nuestro ajuste":{"0":1.6412833647}}
# Eigth time 0.0056018829345703125
#
# Processing Vano 74
#
# Reference G_13578388_13578466
# First time 0.018589019775390625
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 4587509.961551661
# Umbral de corte superior detectado: 4587660.760625235
# Analyzing conductor configuration
# Third time 0.43498969078063965
# Number of lines: 3
# Fourth time 0.002467632293701172
# Starting fit
# Prefit data shape (3, 4441)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 4.197130441665649
# clustering time 2 0.0016410350799560547
# clustering time 4.199855327606201
# Fifth time 4.2041614055633545
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.5888080991372691, 0.9810955631224467
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8083565761607314, 0.7914910090270225
# RmeanSE and RmaxSE error for z coordinate: 0.22621674482024906, 1.002068688443991
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9740769910143403, 0.951379486280955
# RmeanSE and RmaxSE error for z coordinate: 0.16142228297472366, 0.6005970217009543
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9868854272708647, 0.9839271995855604
# Sixth time 0.01741790771484375
# Evaluating fit
# Seventh time 0.005895376205444336
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578388_13578466"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.54%"},"Error polil\u00ednea":{"0":4587585.6541522071},"Error nuestro ajuste":{"0":0.8035018595}}
# Eigth time 0.005326986312866211
#
# Processing Vano 75
#
# Reference G_13576895_13576896
# First time 0.025393009185791016
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -2792106.6263862625
# Umbral de corte superior detectado: -2791965.410302902
# Analyzing conductor configuration
# Third time 0.7321324348449707
# Number of lines: 6
# Fourth time 0.002434968948364258
# Starting fit
# Prefit data shape (3, 8055)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 22.29133653640747
# clustering time 2 0.0022084712982177734
# clustering time 22.294955730438232
# Fifth time 22.299050092697144
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.8781504139478057, 1.258127071976237
# Fit Pearson R and Fit Spearman R for z coordinate: 0.4783886506953858, 0.4605521434901783
# RmeanSE and RmaxSE error for z coordinate: 0.6013750035918916, 1.6456329047607867
# Fit Pearson R and Fit Spearman R for z coordinate: 0.7989703867597866, 0.9125207062965859
# RmeanSE and RmaxSE error for z coordinate: 0.4672098116302085, 1.042529740776542
# Fit Pearson R and Fit Spearman R for z coordinate: 0.8841464765382101, 0.8938375350140055
# Sixth time 0.02402520179748535
# Evaluating fit
# Seventh time 0.009732723236083984
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13576895_13576896"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.03%"},"Error polil\u00ednea":{"0":2792035.6840918106},"Error nuestro ajuste":{"0":1.59114911}}
# Eigth time 0.006967067718505859
#
# Processing Vano 76
#
# Reference G_13578431_13578442
# First time 0.023951053619384766
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: 1068458.4909247956
# Analyzing conductor configuration
# Third time 0.4096333980560303
# Number of lines: 3
# Fourth time 0.0025229454040527344
# Starting fit
# Prefit data shape (3, 4430)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 1.8555469512939453
# clustering time 2 0.0020036697387695312
# clustering time 1.8585126399993896
# Fifth time 1.8636739253997803
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.035837252727381565, 0.1262473250655331
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9993576412308587, 0.9938811746027404
# RmeanSE and RmaxSE error for z coordinate: 0.052025015674494975, 0.18318954842745327
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9986458089743475, 0.9984695347089114
# RmeanSE and RmaxSE error for z coordinate: 0.12458739509564526, 0.3924768431307357
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9922086378297565, 0.9908673020973139
# Sixth time 0.01781916618347168
# Evaluating fit
# Seventh time 0.005726814270019531
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578431_13578442"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 10.45%"},"Error polil\u00ednea":{"0":1068502.3782977667},"Error nuestro ajuste":{"0":1.3332558435}}
# Eigth time 0.004062175750732422
#
# Processing Vano 77
#
# Reference G_13578289_13578477
# First time 0.012367963790893555
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -4571557.87253553
# Analyzing conductor configuration
# Third time 0.11339688301086426
# Number of lines: 3
# Fourth time 0.0015063285827636719
# Starting fit
# Prefit data shape (3, 2326)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 0.6088638305664062
# clustering time 2 0.0013382434844970703
# clustering time 0.6107649803161621
# Fifth time 0.61458420753479
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.037871033647634465, 0.085698232348971
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9992826379546496, 0.9981236690473129
# RmeanSE and RmaxSE error for z coordinate: 0.02089879883295764, 0.04942755237619023
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9997815962535723, 0.9943537118378798
# RmeanSE and RmaxSE error for z coordinate: 0.05543284105949356, 0.14161630750057438
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9984624182669608, 0.9981083775626121
# Sixth time 0.018600940704345703
# Evaluating fit
# Seventh time 0.006014347076416016
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578289_13578477"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.42%"},"Error polil\u00ednea":{"0":4571512.0566536998},"Error nuestro ajuste":{"0":1.264142098}}
# Eigth time 0.0060787200927734375
#
# Processing Vano 78
#
# Reference G_13578359_13578403
# First time 0.020761489868164062
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -707978.9610101274
# Analyzing conductor configuration
# Third time 0.5001041889190674
# Number of lines: 3
# Fourth time 0.002752065658569336
# Starting fit
# Prefit data shape (3, 5188)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 4.4013352394104
# clustering time 2 0.002226114273071289
# clustering time 4.4049201011657715
# Fifth time 4.410997629165649
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.4062223542959542, 0.8111896614782035
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9139103086454364, 0.8848941038589115
# RmeanSE and RmaxSE error for z coordinate: 0.1398923627444128, 0.5288612910000514
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9901675364192607, 0.9894298580165761
# RmeanSE and RmaxSE error for z coordinate: 0.17336457233771851, 0.4281017222331034
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9848577182198741, 0.9267206477732794
# Sixth time 0.019231796264648438
# Evaluating fit
# Seventh time 0.006558656692504883
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578359_13578403"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.06%"},"Error polil\u00ednea":{"0":707910.1138603502},"Error nuestro ajuste":{"0":1.3601121172}}
# Eigth time 0.004984378814697266
#
# Processing Vano 79
#
# Reference G_13578340_13578436
# First time 0.014071941375732422
# Rotating vano
# Cropping conductor
# Umbral de corte superior detectado: -707875.9207043244
# Umbral de corte superior detectado: -707736.0360316603
# Analyzing conductor configuration
# Third time 0.4345715045928955
# Number of lines: 3
# Fourth time 0.0023920536041259766
# Starting fit
# Prefit data shape (3, 4549)
# Applying spectral clustering
# /home/ubuntu-deduce/Projects/electra-ia/.venv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# clustering time 1 5.652220010757446
# clustering time 2 0.0017158985137939453
# clustering time 5.654557943344116
# Fifth time 5.661005735397339
# Fitting catenaria to data
# RmeanSE and RmaxSE error for z coordinate: 0.21652491905195476, 0.9767215064273378
# Fit Pearson R and Fit Spearman R for z coordinate: 0.976456996512693, 0.9639202553790456
# RmeanSE and RmaxSE error for z coordinate: 0.04423684224969387, 0.10166074081127563
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9990236920136962, 0.9832763530846487
# RmeanSE and RmaxSE error for z coordinate: 0.26344197851722323, 0.5659774969096103
# Fit Pearson R and Fit Spearman R for z coordinate: 0.9646752427416396, 0.9061624649859944
# Sixth time 0.01947164535522461
# Evaluating fit
# Seventh time 0.007920026779174805
# Reconstructing X axis
# Setting vano score
# Vano score {"Vano":{"0":"G_13578340_13578436"},"Reconstrucci\u00f3n":{"0":"Posible"},"Flag":{"0":"Tiene 3 o m\u00e1s conductores. Porcentaje de huecos: 0.09%"},"Error polil\u00ednea":{"0":707805.3106384816},"Error nuestro ajuste":{"0":1.6833805939}}
# Eigth time 0.004374980926513672

# %%
print(f"Mean RMSE and mean RmaxSE: {np.array(rmses).mean().mean()}, {np.array(maxes).mean().mean()}")
print(f"Mean correlation R Pearson and Spearman: {np.array(correlations)[:,0].mean().mean()}, {np.array(correlations)[:,1].mean().mean()}")
# Out:
# Mean RMSE and mean RmaxSE: 0.4305814212432351, 0.9421215104796961
# Mean correlation R Pearson and Spearman: 0.7942743949928487, 0.7840778774699445

# %%
np.array(rmses).flatten() > 0.9
# Out:
# array([False,  True,  True,  True, False, False,  True, False, False,
#        False, False,  True, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False,  True,  True, False,
#        False, False, False, False, False,  True, False,  True,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False,  True, False,  True, False,  True,  True, False,
#        False,  True, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False, False,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
plt.figure(figsize=(12,8))

plt.subplot(121)
plt.hist(np.array(rmses).flatten())
plt.subplot(122)
plt.hist(np.array(maxes).flatten())

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

plt.subplot(121)
plt.hist(np.array(correlations)[:,0].flatten())
plt.subplot(122)
plt.hist(np.array(correlations)[:,1].flatten())

plt.tight_layout()
plt.show()

# %%
puntuaciones = []

for vano in data:

    try:
        puntuaciones.append(vano["PUNTUACIONES"])
        
    except Exception:
        pass

puntuaciones_df = pd.DataFrame(puntuaciones)

print((puntuaciones_df["Reconstrucción"] == "Posible").sum()/puntuaciones_df.shape[0])
print((puntuaciones_df["Error polilínea"] > puntuaciones_df["Error nuestro ajuste"]).sum()/puntuaciones_df.shape[0])
print((puntuaciones_df["Output"] == "good_fit").sum()/puntuaciones_df.shape[0])
# Out:
# 0.95
# 0.825
# 0.825

# %%
puntuaciones_df.describe().loc[["mean", "std", "max", "std"],:]
# Out:
#       Error polilínea  Error nuestro ajuste  Conductores identificados
# mean     2.061987e+06              1.093805                   3.446809
# std      1.768118e+06              0.720189                   1.754603
# max      4.694515e+06              2.743084                   7.000000
# std      1.768118e+06              0.720189                   1.754603

# %%
# Out:
#   Reconstrucción                                               Flag  \
# 0        Posible  Tiene 3 o más conductores. Porcentaje de hueco...
#
#    Error polilínea  Error nuestro ajuste Continuidad  \
# 0        39.932749             45.434766        full
#
#    Conductores identificados    Output
# 0                          3  good_fit

# %%
res.loc[res.flag=='empty',:].shape
# Out:
# (1, 3)

# %%
res.loc[res.flag=='bad_cluster',:].shape
# Out:
# (11, 3)

# %%
res.loc[res.flag=='bad_backing',:]
# Out:
#                      id         flag  line_number
# 13  G_13576748_13576812  bad_backing            0

# %%
res.loc[res.flag=='good_fit',:].shape
# Out:
# (0, 3)

# %%
from catenaria.notebooks.old_modules.modules_fit import *
import json
import os

pathdata2 = os.getcwd()+"/../data/lineas_completas/REG804.json"

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)
    
fulld=[data[i]['ID_VANO'] for i in range(len(data))]
res=fit_plot_vano_group(data,sublist=fulld,plot_filter='good_fit',init=0,end=len(fulld),save=True,label='REG')#len(fulld)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from modules_fit import *
#       2 import json
#       3 import os
#
# File ~/projects/1electra-ia/electra-ia/catenaria/notebooks/modules_fit.py:3
#       2 import json
# ----> 3 import plotly.graph_objects as go
#       4 from matplotlib.patches import Ellipse
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'plotly'

# %%
res.flag.value_counts()
# Out:
# flag
# bad_cluster        87
# bad_line_number    43
# good_fit            9
# empty               9
# bad_backing         7
# Name: count, dtype: int64

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
from catenaria.notebooks.old_modules.modules_fit import *
import json
import os

pathdata2 = os.getcwd()+"/../data/lineas_completas/XIN803.json"

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)
    

fulld=[data[i]['ID_VANO'] for i in range(len(data))]
res=fit_plot_vano_group(data,sublist=fulld,plot_filter=None,init=0,end=len(fulld),save=True,label='XIN')#len(fulld)
#'bad_line_number', "bad_backing", bad_cluster, bad_line_number, bad_line_orientation, bad_fit, good_fit,
# Out:
# Processing Vano 0
#
# Reference G_13645821_13645987
# Umbral de corte superior detectado: 851254.4582811123
# Number of lines: 3
# (8040,)
# [0 1 2]
# (3,)
#
# Processing Vano 1
#
# Reference G_13645776_13645990
# Umbral de corte inferior detectado: 4359432.5516279405
# Umbral de corte superior detectado: 4359553.768260339
# Number of lines: 3
# (8546,)
# [0 1 2]
# (3,)
#
# Processing Vano 2
#
# Reference G_13645684_13645777
# Umbral de corte inferior detectado: 251440.5701692517
# Umbral de corte superior detectado: 251528.8044695908
# Number of lines: 3
# (5596,)
# [0 1 2]
# (3,)
#
# Processing Vano 3
#
# Reference G_13615863_13645824
# Umbral de corte inferior detectado: -1043461.5826490528
# Umbral de corte superior detectado: -1043410.1842453678
# Number of lines: 3
# (2878,)
# [0 1 2]
# (3,)
#
# Processing Vano 4
#
# Reference G_13645732_13645823
# Umbral de corte inferior detectado: -1102312.024197021
# Umbral de corte superior detectado: -1102159.7647004905
# Number of lines: 3
# (5945,)
# [0 1 2]
# (3,)
#
# Processing Vano 5
#
# Reference G_13499432_13645947
# Umbral de corte inferior detectado: 3885699.6785727055
# Umbral de corte superior detectado: 3885769.21114299
# Number of lines: 3
# (2794,)
# [0 1 2]
# (3,)
#
# Processing Vano 6
#
# Reference G_13645686_13645952
# Umbral de corte superior detectado: 4666594.092476362
# Number of lines: 3
# (4809,)
# [0 1 2]
# (3,)
#
# Processing Vano 7
#
# Reference G_13037116_13511437
# Umbral de corte superior detectado: -3847984.600555575
# Number of lines: 0
#
# Processing Vano 8
#
# Reference G_13618881_13645690
# Umbral de corte inferior detectado: -2996628.7497691694
# Umbral de corte superior detectado: -2996498.8021569364
# Number of lines: 3
# (6613,)
# [0 1 2]
# (3,)
#
# Processing Vano 9
#
# Reference G_13645790_13645962
# Umbral de corte inferior detectado: -2331359.7217288734
# Umbral de corte superior detectado: -2331178.785764275
# Number of lines: 3
# (10535,)
# [0 1 2]
# (3,)
#
# Processing Vano 10
#
# Reference G_13645744_13645920
# Umbral de corte inferior detectado: -4176300.9969148505
# Number of lines: 3
# (9374,)
# [0 1 2]
# (3,)
#
# Processing Vano 11
#
# Reference G_13645844_13645888
# Umbral de corte inferior detectado: -3641756.7046999033
# Umbral de corte superior detectado: -3641606.1306332494
# Number of lines: 3
# (6834,)
# [0 1 2]
# (3,)
#
# Processing Vano 12
#
# Reference G_13645647_13645791
# Umbral de corte inferior detectado: -2813610.2452910524
# Number of lines: 3
# (5558,)
# [0 1 2]
# (3,)
#
# Processing Vano 13
#
# Reference G_13645750_13645842
# Umbral de corte inferior detectado: -4654753.936008494
# Umbral de corte superior detectado: -4654600.675051804
# Number of lines: 3
# (5912,)
# [0 1 2]
# (3,)
#
# Processing Vano 14
#
# Reference G_13645707_13645750
# Umbral de corte inferior detectado: -4654146.60955512
# Umbral de corte superior detectado: -4654004.1421135105
# Number of lines: 3
# (11357,)
# [0 1 2]
# (3,)
#
# Processing Vano 15
#
# Reference G_13645718_13645899
# Umbral de corte superior detectado: -1702966.4943246911
# Number of lines: 3
# (2488,)
# [0 1 2]
# (3,)
#
# Processing Vano 16
#
# Reference G_13645765_13645809
# Umbral de corte superior detectado: -4577344.45774525
# Number of lines: 3
# (3825,)
# [0 1 2]
# (3,)
#
# Processing Vano 17
#
# Reference G_13645665_13645719
# Umbral de corte superior detectado: -4577007.859618036
# Number of lines: 3
# (3724,)
# [0 1 2]
# (3,)
#
# Processing Vano 18
#
# Reference G_13088932_13645854
# Umbral de corte inferior detectado: 4576554.291719606
# Number of lines: 3
# (4937,)
# [0 1 2]
# (3,)
#
# Processing Vano 19
#
# Reference G_13145989_13645938
# Umbral de corte superior detectado: 1674860.089117002
# Number of lines: 3
# (5390,)
# [0 1 2]
# (3,)
#
# Processing Vano 20
#
# Reference G_13645721_13645813
# Umbral de corte inferior detectado: 1687755.1038813074
# Umbral de corte superior detectado: 1687849.2968910318
# Number of lines: 3
# (3221,)
# [0 1 2]
# (3,)
#
# Processing Vano 21
#
# Reference G_13645767_13645812
# Umbral de corte inferior detectado: 59833.77234631706
# Umbral de corte superior detectado: 59916.99459881367
# Number of lines: 3
# (4476,)
# [0 1 2]
# (3,)
#
# Processing Vano 22
#
# Reference G_13645817_13645977
# Umbral de corte inferior detectado: -4652974.2459114995
# Number of lines: 3
# (4620,)
# [0 1 2]
# (3,)
#
# Processing Vano 23
#
# Reference G_13645668_13645817
# Umbral de corte inferior detectado: -4653764.105477329
# Number of lines: 3
# (7104,)
# [0 1 2]
# (3,)
#
# Processing Vano 24
#
# Reference G_13645771_13645980
# Umbral de corte inferior detectado: -835115.056291599
# Number of lines: 3
# (5607,)
# [0 1 2]
# (3,)
#
# Processing Vano 25
#
# Reference G_13645819_13645906
# Umbral de corte inferior detectado: -4628150.39050773
# Umbral de corte superior detectado: -4628015.832841758
# Number of lines: 3
# (3797,)
# [0 1 2]
# (3,)
#
# Processing Vano 26
#
# Reference G_13645819_13645981
# Umbral de corte inferior detectado: -4628207.894185086
# Number of lines: 3
# (4751,)
# [0 1 2]
# (3,)
#
# Processing Vano 27
#
# Reference G_13645981_13645982
# Umbral de corte inferior detectado: -4636799.429019425
# Umbral de corte superior detectado: -4636662.920555141
# Number of lines: 3
# (5734,)
# [0 1 2]
# (3,)
#
# Processing Vano 28
#
# Reference G_13645776_13645989
# Umbral de corte superior detectado: -4356796.973020418
# Number of lines: 3
# (4794,)
# [0 1 2]
# (3,)
#
# Processing Vano 29
#
# Reference G_13645683_13645951
# Umbral de corte inferior detectado: 252960.55379837585
# Umbral de corte superior detectado: 253189.62948276833
# Number of lines: 3
# (9298,)
# [0 1 2]
# (3,)
#
# Processing Vano 30
#
# Reference G_13645681_13645867
# Umbral de corte superior detectado: 1228158.260604998
# Number of lines: 3
# (5641,)
# [0 1 2]
# (3,)
#
# Processing Vano 31
#
# Reference G_13645733_13645868
# Umbral de corte inferior detectado: 979661.9896831275
# Umbral de corte superior detectado: 979793.6453535401
# Number of lines: 3
# (2741,)
# [0 1 2]
# (3,)
#
# Processing Vano 32
#
# Reference G_13645738_13645781
# Umbral de corte inferior detectado: 2286672.2791546406
# Umbral de corte superior detectado: 2286899.2390558813
# Number of lines: 3
# (9654,)
# [0 1 2]
# (3,)
#
# Processing Vano 33
#
# Reference G_13645687_13645874
# Umbral de corte inferior detectado: 130703.67660628467
# Number of lines: 3
# (5707,)
# [0 1 2]
# (3,)
#
# Processing Vano 34
#
# Reference G_13645737_13645873
# Umbral de corte inferior detectado: 4667027.11407635
# Umbral de corte superior detectado: 4667138.650850242
# Number of lines: 3
# (4827,)
# [0 1 2]
# (3,)
#
# Processing Vano 35
#
# Reference G_13511437_13511438
# Umbral de corte superior detectado: -3840803.5530345435
# Number of lines: 3
# (4465,)
# [0 1 2]
# (3,)
#
# Processing Vano 36
#
# Reference G_13645910_13645956
# Umbral de corte superior detectado: 2290741.540205456
# Number of lines: 3
# (7163,)
# [0 1 2]
# (3,)
#
# Processing Vano 37
#
# Reference G_13645695_13645696
# Umbral de corte superior detectado: -4609142.756080399
# Number of lines: 3
# (6005,)
# [0 1 2]
# (3,)
#
# Processing Vano 38
#
# Reference G_13597802_13645916
# Umbral de corte superior detectado: -4610365.948823022
# Number of lines: 3
# (5206,)
# [0 1 2]
# (3,)
#
# Processing Vano 39
#
# Reference G_13645947_13645992
# Umbral de corte superior detectado: 969472.8462436589
# Number of lines: 3
# (3547,)
# [0 1 2]
# (3,)
#
# Processing Vano 40
#
# Reference G_13645661_13645713
#
# Processing Vano 41
#
# Reference G_13645798_13645842
# Umbral de corte inferior detectado: -4654241.40658729
# Umbral de corte superior detectado: -4654143.354797946
# Number of lines: 3
# (5241,)
# [0 1 2]
# (3,)
#
# Processing Vano 42
#
# Reference G_13645720_13645855
# Umbral de corte inferior detectado: -4576215.528637716
# Umbral de corte superior detectado: -4576096.5029573785
# Number of lines: 3
# (3349,)
# [0 1 2]
# (3,)
#
# Processing Vano 43
#
# Reference G_13645809_13645810
# Umbral de corte inferior detectado: -4576050.494083888
# Number of lines: 3
# (5189,)
# [0 1 2]
# (3,)
#
# Processing Vano 44
#
# Reference G_13645722_13645939
# Umbral de corte inferior detectado: -4652509.511348185
# Number of lines: 3
# (4911,)
# [0 1 2]
# (3,)
#
# Processing Vano 45
#
# Reference G_13645816_13645900
# Umbral de corte inferior detectado: -3184952.600411098
# Umbral de corte superior detectado: -3184745.7754998095
# Number of lines: 3
# (6352,)
# [0 1 2]
# (3,)
#
# Processing Vano 46
#
# Reference G_13645772_13645944
# Umbral de corte inferior detectado: -840655.7062288013
# Umbral de corte superior detectado: -840477.9400604869
# Number of lines: 3
# (8539,)
# [0 1 2]
# (3,)
#
# Processing Vano 47
#
# Reference G_13645821_13645862
# Umbral de corte inferior detectado: -4670868.287910004
# Umbral de corte superior detectado: -4670867.871240305
# Number of lines: 0
#
# Processing Vano 48
#
# Reference G_13645727_13645822
# Umbral de corte inferior detectado: -847799.3130634299
# Number of lines: 3
# (4910,)
# [0 1 2]
# (3,)
#
# Processing Vano 49
#
# Reference G_13645683_13645684
# Umbral de corte inferior detectado: 248473.3143338801
# Umbral de corte superior detectado: 248684.2268704311
# Number of lines: 3
# (7410,)
# [0 1 2]
# (3,)
#
# Processing Vano 50
#
# Reference G_13645947_13645993
# Umbral de corte inferior detectado: -982646.7185340405
# Umbral de corte superior detectado: -982502.3164895311
# Number of lines: 3
# (3587,)
# [0 1 2]
# (3,)
#
# Processing Vano 51
#
# Reference G_13645909_13645950
# Umbral de corte inferior detectado: 4579799.6317419
# Umbral de corte superior detectado: 4579999.267062851
# Number of lines: 3
# (7477,)
# [0 1 2]
# (3,)
#
# Processing Vano 52
#
# Reference G_13645688_13645781
# Umbral de corte superior detectado: -2281158.5706371907
# Number of lines: 3
# (6084,)
# [0 1 2]
# (3,)
#
# Processing Vano 53
#
# Reference G_13037123_13645874
# Umbral de corte inferior detectado: 126452.8233642389
# Number of lines: 3
# (8806,)
# [0 1 2]
# (3,)
#
# Processing Vano 54
#
# Reference G_13645954_13645956
# Umbral de corte inferior detectado: -2289734.8804847864
# Umbral de corte superior detectado: -2289604.3803263432
# Number of lines: 3
# (6031,)
# [0 1 2]
# (3,)
#
# Processing Vano 55
#
# Reference G_13645954_13645996
# Umbral de corte inferior detectado: -2296274.66006667
# Number of lines: 3
# (5124,)
# [0 1 2]
# (3,)
#
# Processing Vano 56
#
# Reference G_13645875_13645996
# Umbral de corte superior detectado: -2296894.5409270413
# Number of lines: 3
# (9347,)
# [0 1 2]
# (3,)
#
# Processing Vano 57
#
# Reference G_13645641_13645642
# Umbral de corte inferior detectado: -4084010.1717578275
# Umbral de corte superior detectado: -4083912.8986448515
# Number of lines: 3
# (7143,)
# [0 1 2]
# (3,)
#
# Processing Vano 58
#
# Reference G_13645696_13645697
# Umbral de corte inferior detectado: -4608743.069734835
# Umbral de corte superior detectado: -4608528.055396839
# Number of lines: 3
# (7640,)
# [0 1 2]
# (3,)
#
# Processing Vano 59
#
# Reference G_13645862_13645986
# Umbral de corte inferior detectado: -4668490.964345153
# Number of lines: 0
#
# Processing Vano 60
#
# Reference G_13645872_13645952
# Umbral de corte superior detectado: 4666608.056881509
# Number of lines: 3
# (6136,)
# [0 1 2]
# (3,)
#
# Processing Vano 61
#
# Reference G_13645712_13645761
#
# Processing Vano 62
#
# Reference G_13645752_13645888
# Umbral de corte inferior detectado: -4116616.1284980373
# Number of lines: 3
# (7362,)
# [0 1 2]
# (3,)
#
# Processing Vano 63
#
# Reference G_13645843_13645927
# Umbral de corte inferior detectado: -4111275.372779807
# Umbral de corte superior detectado: -4111115.690844588
# Number of lines: 3
# (6663,)
# [0 1 2]
# (3,)
#
# Processing Vano 64
#
# Reference G_13645899_13645974
# Umbral de corte inferior detectado: -1703814.4279406783
# Umbral de corte superior detectado: -1703669.4766256048
# Number of lines: 3
# (3730,)
# [0 1 2]
# (3,)
#
# Processing Vano 65
#
# Reference G_13645799_13645843
# Umbral de corte inferior detectado: 4117603.3400835088
# Umbral de corte superior detectado: 4117767.4598341
# Number of lines: 3
# (8405,)
# [0 1 2]
# (3,)
#
# Processing Vano 66
#
# Reference G_13645767_13645813
# Umbral de corte inferior detectado: 1683283.8014260721
# Umbral de corte superior detectado: 1683410.2346572303
# Number of lines: 3
# (4681,)
# [0 1 2]
# (3,)
#
# Processing Vano 67
#
# Reference G_13088936_13645722
# Umbral de corte inferior detectado: -4673185.689941792
# Number of lines: 3
# (6725,)
# [0 1 2]
# (3,)
#
# Processing Vano 68
#
# Reference G_13645943_13645980
# Umbral de corte inferior detectado: -853287.8837653049
# Umbral de corte superior detectado: -853187.7114431662
# Number of lines: 3
# (6521,)
# [0 1 2]
# (3,)
#
# Processing Vano 69
#
# Reference G_13088932_13149467
# Umbral de corte inferior detectado: -3011396.4239172176
# Number of lines: 0
#
# Processing Vano 70
#
# Reference G_13645727_13645987
# Umbral de corte inferior detectado: -848795.875700173
# Number of lines: 3
# (5072,)
# [0 1 2]
# (3,)
#
# Processing Vano 71
#
# Reference G_13645681_13645775
# Umbral de corte inferior detectado: -1221748.4542189916
# Umbral de corte superior detectado: -1221584.2019205946
# Number of lines: 3
# (9836,)
# [0 1 2]
# (3,)
#
# Processing Vano 72
#
# Reference G_13645681_13645990
# Umbral de corte superior detectado: 4357410.73399668
# Number of lines: 0
#
# Processing Vano 73
#
# Reference G_13645731_13645989
# Umbral de corte inferior detectado: 4366475.980302282
# Umbral de corte superior detectado: 4366587.29985132
# Number of lines: 3
# (4787,)
# [0 1 2]
# (3,)
#
# Processing Vano 74
#
# Reference G_13037116_13645688
# Umbral de corte superior detectado: -2284760.452131935
# Number of lines: 3
# (6855,)
# [0 1 2]
# (3,)
#
# Processing Vano 75
#
# Reference G_13645873_13645953
# Umbral de corte inferior detectado: 4666846.87391531
# Umbral de corte superior detectado: 4666966.072176721
# Number of lines: 3
# (3650,)
# [0 1 2]
# (3,)
#
# Processing Vano 76
#
# Reference G_13645686_13645953
# Umbral de corte superior detectado: -4666677.984869267
# Number of lines: 3
# (3860,)
# [0 1 2]
# (3,)
#
# Processing Vano 77
#
# Reference G_13037116_13645875
# Umbral de corte inferior detectado: 2300723.288962941
# Umbral de corte superior detectado: 2300819.998057493
# Number of lines: 3
# (5980,)
# [0 1 2]
# (3,)
#
# Processing Vano 78
#
# Reference G_13645645_13645918
# Umbral de corte inferior detectado: -516400.84596794005
# Umbral de corte superior detectado: -516247.43622643594
# Number of lines: 3
# (5080,)
# [0 1 2]
# (3,)
#
# Processing Vano 79
#
# Reference G_13645698_13645741
# Umbral de corte inferior detectado: -4472358.655318556
# Number of lines: 3
# (5730,)
# [0 1 2]
# (3,)
#
# Processing Vano 80
#
# Reference G_13645642_13645643
# Umbral de corte inferior detectado: -4083774.076349646
# /home/ubuntu-deduce/Projects/electra-ia/catenaria/notebooks/modules_fit.py:1102: RuntimeWarning: overflow encountered in cosh
#   r=a * np.cosh((x - h) / a) + k
# Number of lines: 3
# (7305,)
# [0 1 2]
# (3,)
#
# Processing Vano 81
#
# Reference G_13597802_13645695
# Umbral de corte inferior detectado: -4608989.422519232
# Umbral de corte superior detectado: -4608786.053238494
# Number of lines: 3
# (6673,)
# [0 1 2]
# (3,)
#
# Processing Vano 82
#
# Reference G_13645789_13645916
# Umbral de corte inferior detectado: -4609443.617692309
# Umbral de corte superior detectado: -4609292.996995143
# Number of lines: 3
# (6045,)
# [0 1 2]
# (3,)
#
# Processing Vano 83
#
# Reference G_13645645_13645961
# Umbral de corte superior detectado: 2332713.1473456793
# Number of lines: 3
# (7084,)
# [0 1 2]
# (3,)
#
# Processing Vano 84
#
# Reference G_13645844_13645845
# Umbral de corte inferior detectado: -3638207.696426026
# Umbral de corte superior detectado: -3638057.507208752
# Number of lines: 3
# (7277,)
# [0 1 2]
# (3,)
#
# Processing Vano 85
#
# Reference G_13645799_13645970
# Umbral de corte inferior detectado: -4116335.2849874254
# Umbral de corte superior detectado: -4116117.9422650244
# Number of lines: 3
# (7738,)
# [0 1 2]
# (3,)
#
# Processing Vano 86
#
# Reference G_13149467_13645937
# Umbral de corte superior detectado: -2354220.2445202684
# Number of lines: 3
# (4100,)
# [0 1 2]
# (3,)
#
# Processing Vano 87
#
# Reference G_13088936_13645811
# Umbral de corte inferior detectado: -4673356.1997763105
# Number of lines: 3
# (6589,)
# [0 1 2]
# (3,)
#
# Processing Vano 88
#
# Reference G_13645666_13645855
# Umbral de corte inferior detectado: -2872206.373782538
# Number of lines: 3
# (3814,)
# [0 1 2]
# (3,)
#
# Processing Vano 89
#
# Reference G_13645719_13645765
# Umbral de corte superior detectado: -4578083.174580304
# Number of lines: 3
# (2781,)
# [0 1 2]
# (3,)
#
# Processing Vano 90
#
# Reference G_13645845_13645928
# Umbral de corte inferior detectado: -3153375.649116647
# Umbral de corte superior detectado: -3153218.640044276
# Number of lines: 3
# (6092,)
# [0 1 2]
# (3,)
#
# Processing Vano 91
#
# Reference G_13645821_13645984
# Umbral de corte inferior detectado: -841766.3503859587
# Umbral de corte superior detectado: -841563.194429874
# Number of lines: 3
# (8605,)
# [0 1 2]
# (3,)
#
# Processing Vano 92
#
# Reference G_13645678_13645861
# Umbral de corte superior detectado: 838132.6348398544
# Number of lines: 3
# (9761,)
# [0 1 2]
# (3,)
#
# Processing Vano 93
#
# Reference G_13645861_13645983
# Umbral de corte superior detectado: -843323.5628937371
# Number of lines: 3
# (9382,)
# [0 1 2]
# (3,)
#
# Processing Vano 94
#
# Reference G_13645946_13645983
# Umbral de corte inferior detectado: 838390.9765827759
# Umbral de corte superior detectado: 838504.4550432732
# Number of lines: 3
# (6251,)
# [0 1 2]
# (3,)
#
# Processing Vano 95
#
# Reference G_13645679_13645985
# Umbral de corte inferior detectado: -4666457.384368639
# Number of lines: 3
# (2106,)
# [0 1 2]
# (3,)
#
# Processing Vano 96
#
# Reference G_13645824_13645991
# Umbral de corte inferior detectado: 229491.58031456373
# Umbral de corte superior detectado: 229623.5319829731
# Number of lines: 3
# (5322,)
# [0 1 2]
# (3,)
#
# Processing Vano 97
#
# Reference G_13645948_13645993
# Umbral de corte superior detectado: 988068.3055350069
# Number of lines: 3
# (2944,)
# [0 1 2]
# (3,)
#
# Processing Vano 98
#
# Reference G_13645869_13645870
# Umbral de corte inferior detectado: 4580916.193007618
# Umbral de corte superior detectado: 4581030.432399943
# Number of lines: 3
# (3063,)
# [0 1 2]
# (3,)
#
# Processing Vano 99
#
# Reference G_13645829_13645911
# Umbral de corte inferior detectado: -4429054.127465501
# Umbral de corte superior detectado: -4428885.801047778
# Number of lines: 3
# (7985,)
# [0 1 2]
# (3,)
#
# Processing Vano 100
#
# Reference G_13645739_13645998
#
# Processing Vano 101
#
# Reference G_13645742_13645961
# Umbral de corte inferior detectado: -2331607.011052962
# Number of lines: 3
# (9812,)
# [0 1 2]
# (3,)
#
# Processing Vano 102
#
# Reference G_13645713_13645897
# Umbral de corte inferior detectado: -4637100.136336711
# Umbral de corte superior detectado: -4637009.026218782
# Number of lines: 3
# (4274,)
# [0 1 2]
# (3,)
#
# Processing Vano 103
#
# Reference G_13645712_13645897
# Umbral de corte inferior detectado: -4609362.33726288
# Umbral de corte superior detectado: -4609205.483769522
# Number of lines: 3
# (5740,)
# [0 1 2]
# (3,)
#
# Processing Vano 104
#
# Reference G_13645752_13645927
# Umbral de corte inferior detectado: 4117214.9278141214
# Umbral de corte superior detectado: 4117356.942374408
# Number of lines: 3
# (5198,)
# [0 1 2]
# (3,)
#
# Processing Vano 105
#
# Reference G_13088932_13645974
# Umbral de corte inferior detectado: -4365357.129328339
# Umbral de corte superior detectado: -4365233.632738958
# Number of lines: 3
# (3869,)
# [0 1 2]
# (3,)
#
# Processing Vano 106
#
# Reference G_13645666_13645811
# Umbral de corte superior detectado: -2880120.0509223556
# Number of lines: 3
# (3364,)
# [0 1 2]
# (3,)
#
# Processing Vano 107
#
# Reference G_13645720_13645976
# Umbral de corte inferior detectado: -4577630.6020028
# Umbral de corte superior detectado: -4577480.111960245
# Number of lines: 0
#
# Processing Vano 108
#
# Reference G_13088936_13145989
# Umbral de corte inferior detectado: 1699728.1817951177
# Number of lines: 0
#
# Processing Vano 109
#
# Reference G_13645674_13645942
# Umbral de corte inferior detectado: -849598.2622036695
# Umbral de corte superior detectado: -849487.5832133703
# Number of lines: 3
# (6165,)
# [0 1 2]
# (3,)
#
# Processing Vano 110
#
# Reference G_13645905_13645979
# Umbral de corte inferior detectado: -840434.3609041788
# Umbral de corte superior detectado: -840305.4005513965
# Number of lines: 3
# (8053,)
# [0 1 2]
# (3,)
#
# Processing Vano 111
#
# Reference G_92006814_92006815
# Umbral de corte superior detectado: 2721599.84415242
# Number of lines: 0
#
# Processing Vano 112
#
# Reference G_13645946_13645982
# Umbral de corte inferior detectado: -4637690.56621713
# Umbral de corte superior detectado: -4637576.926587466
# Number of lines: 3
# (4292,)
# [0 1 2]
# (3,)
#
# Processing Vano 113
#
# Reference G_13645907_13645946
# Umbral de corte inferior detectado: -4573427.01185381
# Umbral de corte superior detectado: -4573342.080913542
# Number of lines: 3
# (4642,)
# [0 1 2]
# (3,)
#
# Processing Vano 114
#
# Reference G_13645678_13645984
# Umbral de corte inferior detectado: -839075.3268119021
# Number of lines: 3
# (7810,)
# [0 1 2]
# (3,)
#
# Processing Vano 115
#
# Reference G_13645680_13645988
# Umbral de corte inferior detectado: -855873.2009904187
# Umbral de corte superior detectado: -855737.0340365238
# Number of lines: 3
# (6443,)
# [0 1 2]
# (3,)
#
# Processing Vano 116
#
# Reference G_13618881_13645911
# Umbral de corte inferior detectado: -3516061.75181989
# Umbral de corte superior detectado: -3515995.7610803894
# Number of lines: 3
# (4148,)
# [0 1 2]
# (3,)
#
# Processing Vano 117
#
# Reference G_13645910_13645997
# Umbral de corte inferior detectado: -2295805.185717164
# Umbral de corte superior detectado: -2295637.41056058
# Number of lines: 3
# (7535,)
# [0 1 2]
# (3,)
#
# Processing Vano 118
#
# Reference G_13510615_13645645
# Umbral de corte inferior detectado: -4470616.527770416
# Number of lines: 3
# (2271,)
# [0 1 2]
# (3,)
#
# Processing Vano 119
#
# Reference G_13645790_13645920
# Umbral de corte inferior detectado: -4176643.711627153
# Umbral de corte superior detectado: -4176560.593209218
# Number of lines: 3
# (10935,)
# [0 1 2]
# (3,)
#
# Processing Vano 120
#
# Reference G_13645665_13645854
# Umbral de corte inferior detectado: -4578062.992021972
# Umbral de corte superior detectado: -4577909.495587209
# Number of lines: 3
# (5016,)
# [0 1 2]
# (3,)
#
# Processing Vano 121
#
# Reference G_13645772_13645943
# Umbral de corte inferior detectado: 831955.0724122421
# Umbral de corte superior detectado: 832049.0003916533
# Number of lines: 3
# (5709,)
# [0 1 2]
# (3,)
#
# Processing Vano 122
#
# Reference G_13645726_13645859
# Umbral de corte inferior detectado: -4628356.707510173
# Umbral de corte superior detectado: -4628234.158732241
# Number of lines: 3
# (3760,)
# [0 1 2]
# (3,)
#
# Processing Vano 123
#
# Reference G_13645985_13645986
# Umbral de corte inferior detectado: -4668196.875810611
# Number of lines: 3
# (2328,)
# [0 1 2]
# (3,)
#
# Processing Vano 124
#
# Reference G_13615863_13645823
# Umbral de corte inferior detectado: -1102965.8796766158
# Number of lines: 3
# (8424,)
# [0 1 2]
# (3,)
#
# Processing Vano 125
#
# Reference G_13645682_13645732
# Umbral de corte inferior detectado: 1102451.7459240074
# Umbral de corte superior detectado: 1102531.2672137124
# Number of lines: 3
# (6221,)
# [0 1 2]
# (3,)
#
# Processing Vano 126
#
# Reference G_13645682_13645867
# Umbral de corte inferior detectado: -1219879.6647506775
# Umbral de corte superior detectado: -1219775.035111011
# Number of lines: 3
# (7897,)
# [0 1 2]
# (3,)
#
# Processing Vano 127
#
# Reference G_13645733_13645992
# Umbral de corte inferior detectado: 978967.559626212
# Umbral de corte superior detectado: 979048.9675269279
# Number of lines: 3
# (2956,)
# [0 1 2]
# (3,)
#
# Processing Vano 128
#
# Reference G_13645734_13645826
# Umbral de corte inferior detectado: 1353569.122743291
# Umbral de corte superior detectado: 1353742.8450664848
# Number of lines: 3
# (4898,)
# [0 1 2]
# (3,)
#
# Processing Vano 129
#
# Reference G_13037116_13645737
# Umbral de corte inferior detectado: 4665749.097640544
# Umbral de corte superior detectado: 4665787.027201626
# Number of lines: 0
#
# Processing Vano 130
#
# Reference G_13645739_13645997
# Umbral de corte inferior detectado: -2993108.0026694247
# Number of lines: 3
# (5874,)
# [0 1 2]
# (3,)
#
# Processing Vano 131
#
# Reference G_13645843_13645881
# Umbral de corte inferior detectado: -2891694.996838657
# Umbral de corte superior detectado: -2891559.2423161515
# Number of lines: 3
# (5874,)
# [0 1 2]
# (3,)
#
# Processing Vano 132
#
# Reference G_13645791_13645881
# Umbral de corte inferior detectado: -2810240.457632875
# Number of lines: 3
# (6377,)
# [0 1 2]
# (3,)
#
# Processing Vano 133
#
# Reference G_13645707_13645970
# Umbral de corte inferior detectado: -4115899.4046017593
# Umbral de corte superior detectado: -4115805.650431817
# Number of lines: 3
# (5322,)
# [0 1 2]
# (3,)
#
# Processing Vano 134
#
# Reference G_13645717_13645718
# Umbral de corte inferior detectado: -1694071.6281899652
# Umbral de corte superior detectado: -1693994.1549288037
# Number of lines: 3
# (2607,)
# [0 1 2]
# (3,)
#
# Processing Vano 135
#
# Reference G_13149469_13645937
# Umbral de corte superior detectado: -2360854.88350079
# Number of lines: 3
# (3284,)
# [0 1 2]
# (3,)
#
# Processing Vano 136
#
# Reference G_13645810_13645975
# Umbral de corte inferior detectado: -4577558.82497875
# Number of lines: 3
# (4329,)
# [0 1 2]
# (3,)
#
# Processing Vano 137
#
# Reference G_13645721_13645938
# Umbral de corte inferior detectado: 1685944.292944004
# Umbral de corte superior detectado: 1686099.7421863955
# Number of lines: 3
# (4756,)
# [0 1 2]
# (3,)
#
# Processing Vano 138
#
# Reference G_13645668_13645900
# Umbral de corte inferior detectado: -3183151.1548115546
# Umbral de corte superior detectado: -3183051.229296998
# Number of lines: 3
# (5161,)
# [0 1 2]
# (3,)
#
# Processing Vano 139
#
# Reference G_13645675_13645946
# Umbral de corte inferior detectado: -841197.5715939132
# Umbral de corte superior detectado: -841071.4969015371
# Number of lines: 3
# (6403,)
# [0 1 2]
# (3,)
#
# Processing Vano 140
#
# Reference G_13645771_13645942
# Umbral de corte inferior detectado: -843992.0487433944
# Umbral de corte superior detectado: -843820.9774445273
# Number of lines: 3
# (8140,)
# [0 1 2]
# (3,)
#
# Processing Vano 141
#
# Reference G_13645674_13645979
# Umbral de corte inferior detectado: -835687.1892397697
# Umbral de corte superior detectado: -835548.5257035253
# Number of lines: 3
# (7505,)
# [0 1 2]
# (3,)
#
# Processing Vano 142
#
# Reference G_13645859_13645906
# Umbral de corte inferior detectado: -4625407.7052793205
# Umbral de corte superior detectado: -4625303.503389755
# Number of lines: 3
# (3176,)
# [0 1 2]
# (3,)
#
# Processing Vano 143
#
# Reference G_13645641_13645960
# Umbral de corte superior detectado: -4608798.2122943755
# Number of lines: 3
# (6050,)
# [0 1 2]
# (3,)
#
# Processing Vano 144
#
# Reference G_13645680_13645822
# Umbral de corte inferior detectado: -852885.2058064768
# Umbral de corte superior detectado: -852745.8425731794
# Number of lines: 3
# (5865,)
# [0 1 2]
# (3,)
#
# Processing Vano 145
#
# Reference G_13645777_13645991
# Umbral de corte inferior detectado: 251925.4250049805
# Umbral de corte superior detectado: 252066.33702245358
# Number of lines: 3
# (5072,)
# [0 1 2]
# (3,)
#
# Processing Vano 146
#
# Reference G_13037347_13645948
# Umbral de corte inferior detectado: 966413.4261154847
# Umbral de corte superior detectado: 966534.3979201139
# Number of lines: 3
# (2634,)
# [0 1 2]
# (3,)
#
# Processing Vano 147
#
# Reference G_13645870_13645950
# Umbral de corte inferior detectado: 4580925.260156705
# Number of lines: 3
# (5036,)
# [0 1 2]
# (3,)
#
# Processing Vano 148
#
# Reference G_13645871_13645951
# Umbral de corte inferior detectado: 4581176.767971896
# Umbral de corte superior detectado: 4581263.369370632
# Number of lines: 3
# (4903,)
# [0 1 2]
# (3,)
#
# Processing Vano 149
#
# Reference G_13645871_13645909
# Umbral de corte inferior detectado: 4583073.753836801
# Umbral de corte superior detectado: 4583263.780175604
# Number of lines: 3
# (6694,)
# [0 1 2]
# (3,)
#
# Processing Vano 150
#
# Reference G_13645738_13645995
# Umbral de corte inferior detectado: 2284573.623928991
# Umbral de corte superior detectado: 2284728.939097217
# Number of lines: 3
# (8439,)
# [0 1 2]
# (3,)
#
# Processing Vano 151
#
# Reference G_13645687_13645995
# Umbral de corte inferior detectado: 125607.73005866296
# Umbral de corte superior detectado: 125689.45063962987
# Number of lines: 3
# (4496,)
# [0 1 2]
# (3,)
#
# Processing Vano 152
#
# Reference G_13037123_13645951
# Umbral de corte inferior detectado: -250842.1794166031
# Umbral de corte superior detectado: -250712.21029324437
# Number of lines: 3
# (6923,)
# [0 1 2]
# (3,)
#
# Processing Vano 153
#
# Reference G_13645644_13645918
# Umbral de corte inferior detectado: -517002.79901364166
# Umbral de corte superior detectado: -516900.67550530215
# Number of lines: 3
# (7295,)
# [0 1 2]
# (3,)
#
# Processing Vano 154
#
# Reference G_13510615_13645698
# Umbral de corte superior detectado: 4474085.136827534
# Number of lines: 3
# (6440,)
# [0 1 2]
# (3,)
#
# Processing Vano 155
#
# Reference G_13645643_13645741
# Umbral de corte inferior detectado: -4078181.2250836305
# Number of lines: 3
# (8304,)
# [0 1 2]
# (3,)
#
# Processing Vano 156
#
# Reference G_13645697_13645960
# Umbral de corte inferior detectado: -4608071.190846837
# Umbral de corte superior detectado: -4607944.067057428
# Number of lines: 3
# (4194,)
# [0 1 2]
# (3,)
#
# Processing Vano 157
#
# Reference G_13645742_13645962
# Umbral de corte inferior detectado: -2333730.640850518
# Number of lines: 3
# (7909,)
# [0 1 2]
# (3,)
#
# Processing Vano 158
#
# Reference G_13645826_13645909
# Umbral de corte inferior detectado: 1363080.1016106978
# Umbral de corte superior detectado: 1363261.4343730877
# Number of lines: 3
# (4708,)
# [0 1 2]
# (3,)
#
# Processing Vano 159
#
# Reference G_13645647_13645790
# Umbral de corte superior detectado: 2811209.860801299
# Number of lines: 3
# (6150,)
# [0 1 2]
# (3,)
#
# Processing Vano 160
#
# Reference G_13645975_13645976
# Umbral de corte inferior detectado: -4575853.132591385
# Number of lines: 2
#
# Processing Vano 161
#
# Reference G_13645856_13645977
# Umbral de corte inferior detectado: -4653403.775311248
# Number of lines: 3
# (4106,)
# [0 1 2]
# (3,)
#
# Processing Vano 162
#
# Reference G_13645800_13645927
# Umbral de corte inferior detectado: -1554205.663922059
# Number of lines: 0

# %%
from catenaria.notebooks.old_modules.modules_fit import *
import json
import os

pathdata2 = os.getcwd()+"/../data/lineas_completas/VDI711.json"

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)
    

fulld=[data[i]['ID_VANO'] for i in range(len(data))]
res=fit_plot_vano_group(data,sublist=fulld,plot_filter=None,init=0,end=len(fulld),save=True,label='VDI')#len(fulld)
#'bad_line_number', "bad_backing", bad_cluster, bad_line_number, bad_line_orientation, bad_fit, good_fit,
# Out:
# Processing Vano 0
#
# Reference C_13411888_13411889
# Umbral de corte superior detectado: 2617144.872676384
# Number of lines: 3
#
# Processing Vano 1
#
# Reference C_13412048_13412052
# Umbral de corte inferior detectado: -3852391.868572913
# Umbral de corte superior detectado: -3852312.239312542
# Number of lines: 3
#
# Processing Vano 2
#
# Reference C_13412143_13412146
# Umbral de corte superior detectado: 3910548.1512978827
# Number of lines: 3
#
# Processing Vano 3
#
# Reference C_13412119_13412124
# Umbral de corte inferior detectado: 3906191.4814983476
# Umbral de corte superior detectado: 3906279.7072119163
# Number of lines: 3
#
# Processing Vano 4
#
# Reference C_13412096_13412097
# Umbral de corte inferior detectado: 3915462.50963112
# Umbral de corte superior detectado: 3915544.4794009104
# Number of lines: 3
#
# Processing Vano 5
#
# Reference C_13412120_13412145
# Umbral de corte inferior detectado: 3919803.6859338717
# Umbral de corte superior detectado: 3919897.814413377
# Number of lines: 3
#
# Processing Vano 6
#
# Reference C_13412145_13412146
# Umbral de corte superior detectado: -3905711.8167222156
# Number of lines: 3
#
# Processing Vano 7
#
# Reference C_13412137_13412138
# Umbral de corte inferior detectado: 3880915.0384089756
# Number of lines: 3
#
# Processing Vano 8
#
# Reference C_13411659_13412137
# Umbral de corte inferior detectado: 3847212.098086982
# Umbral de corte superior detectado: 3847258.5648974553
# Number of lines: 3
#
# Processing Vano 9
#
# Reference C_13411827_13411828
# Umbral de corte inferior detectado: 3954511.747599976
# Number of lines: 3
#
# Processing Vano 10
#
# Reference C_13411767_13411770
# Umbral de corte inferior detectado: -1423716.6456488243
# Number of lines: 3
#
# Processing Vano 11
#
# Reference C_13411771_13411773
# Umbral de corte superior detectado: 1433355.5732329118
# Number of lines: 3
#
# Processing Vano 12
#
# Reference C_13434443_13434444
# Umbral de corte inferior detectado: 4258749.941388839
# Umbral de corte superior detectado: 4258860.663359526
# Number of lines: 3
#
# Processing Vano 13
#
# Reference C_13411820_13411826
# Umbral de corte inferior detectado: -3859546.14678266
# Umbral de corte superior detectado: -3859438.656814572
# Number of lines: 3
#
# Processing Vano 14
#
# Reference C_13412048_13412050
# Umbral de corte inferior detectado: 3856412.1284652064
# Umbral de corte superior detectado: 3856475.04913755
# Number of lines: 3
#
# Processing Vano 15
#
# Reference C_13411817_13412066
# Umbral de corte superior detectado: -3866936.0955099748
# Number of lines: 3
#
# Processing Vano 16
#
# Reference C_13412141_13412144
# Umbral de corte superior detectado: 3854270.6008667275
# Number of lines: 3
#
# Processing Vano 17
#
# Reference C_13412139_13412140
# Umbral de corte inferior detectado: -3869099.660900093
# Umbral de corte superior detectado: -3869081.4308383036
# Number of lines: 3
#
# Processing Vano 18
#
# Reference C_13412118_13412119
# Umbral de corte inferior detectado: 3905952.144109298
# Umbral de corte superior detectado: 3905989.3488852824
# Number of lines: 3
#
# Processing Vano 19
#
# Reference C_13412147_13412148
# Umbral de corte inferior detectado: 2788682.3157197414
# Umbral de corte superior detectado: 2788819.615613637
# Number of lines: 3
#
# Processing Vano 20
#
# Reference C_13411720_13411728
# Umbral de corte inferior detectado: -4283116.437801388
# Umbral de corte superior detectado: -4282986.705614683
# Number of lines: 3
#
# Processing Vano 21
#
# Reference C_13412045_13412068
# Umbral de corte inferior detectado: 4036056.22198349
# Umbral de corte superior detectado: 4036140.6393890264
# Number of lines: 3
#
# Processing Vano 22
#
# Reference C_13412039_13412045
# Umbral de corte superior detectado: 4037946.7732633515
# Number of lines: 3
#
# Processing Vano 23
#
# Reference C_13434462_13434463
# Umbral de corte inferior detectado: 4058892.8275481034
# Umbral de corte superior detectado: 4058950.0656924904
# Number of lines: 3
#
# Processing Vano 24
#
# Reference C_13434453_13434454
# Umbral de corte superior detectado: 3736063.3130627833
# Number of lines: 3
#
# Processing Vano 25
#
# Reference C_13434481_13434482
# Umbral de corte inferior detectado: 3453357.565262557
# Number of lines: 3
#
# Processing Vano 26
#
# Reference C_13434459_13434460
# Umbral de corte inferior detectado: 3964175.6268334882
# Umbral de corte superior detectado: 3964233.8746428
# Number of lines: 3
#
# Processing Vano 27
#
# Reference C_13434452_13434453
# Umbral de corte inferior detectado: 4260544.70338832
# Umbral de corte superior detectado: 4260641.859509196
# Number of lines: 3
#
# Processing Vano 28
#
# Reference C_13412077_13412085
# Umbral de corte inferior detectado: 4137615.6072664866
# Umbral de corte superior detectado: 4137706.5724375113
# Number of lines: 3
#
# Processing Vano 29
#
# Reference C_13411890_13411891
#
# Processing Vano 30
#
# Reference C_13411884_13411885
# Umbral de corte superior detectado: 4154774.0413879463
# Number of lines: 3
#
# Processing Vano 31
#
# Reference C_13411817_13411822
# Umbral de corte inferior detectado: 3862876.1621702993
# Umbral de corte superior detectado: 3862948.62490467
# Number of lines: 3
#
# Processing Vano 32
#
# Reference C_13412141_13412142
# Umbral de corte inferior detectado: -3865192.82513539
# Umbral de corte superior detectado: -3865156.2003666153
# Number of lines: 3
#
# Processing Vano 33
#
# Reference C_13412097_13412098
# Umbral de corte inferior detectado: 3909560.40023768
# Umbral de corte superior detectado: 3909656.0394976344
# Number of lines: 3
#
# Processing Vano 34
#
# Reference C_13412121_13412127
# Umbral de corte inferior detectado: -3906126.585481908
# Umbral de corte superior detectado: -3906077.7654282437
# Number of lines: 3
#
# Processing Vano 35
#
# Reference C_13412118_13412120
# Umbral de corte superior detectado: -3905808.486683604
# Number of lines: 3
#
# Processing Vano 36
#
# Reference C_13412115_13412133
# Umbral de corte superior detectado: 2778449.6077667815
# Number of lines: 3
#
# Processing Vano 37
#
# Reference C_13412147_13412149
# Umbral de corte inferior detectado: 2781805.183984853
# Umbral de corte superior detectado: 2781958.2487920756
# Number of lines: 3
#
# Processing Vano 38
#
# Reference C_13412116_13412149
# Umbral de corte inferior detectado: 2777851.874263174
# Umbral de corte superior detectado: 2778028.4281215626
# Number of lines: 3
#
# Processing Vano 39
#
# Reference C_13412114_13412117
# Umbral de corte inferior detectado: -2786099.455479899
# Umbral de corte superior detectado: -2785870.2100431346
# Number of lines: 3
#
# Processing Vano 40
#
# Reference C_13411729_13411832
#
# Processing Vano 41
#
# Reference C_13411725_13411730
#
# Processing Vano 42
#
# Reference C_13411774_13411775
# Umbral de corte inferior detectado: -1392153.4326618935
# Umbral de corte superior detectado: -1392107.0470104178
# Number of lines: 3
#
# Processing Vano 43
#
# Reference C_13412035_13412041
# Umbral de corte inferior detectado: -4037419.7909858814
# Umbral de corte superior detectado: -4037352.218166775
# Number of lines: 3
#
# Processing Vano 44
#
# Reference C_13412035_13421440
# Umbral de corte superior detectado: -4037930.9826345267
# Number of lines: 3
#
# Processing Vano 45
#
# Reference C_13434460_13434462
# Umbral de corte inferior detectado: 3955085.0992378294
# Number of lines: 3
#
# Processing Vano 46
#
# Reference C_13434456_13434457
# Umbral de corte inferior detectado: 3742105.624358308
# Number of lines: 3
#
# Processing Vano 47
#
# Reference C_13434440_13434441
# Umbral de corte inferior detectado: 3737153.5322711673
# Umbral de corte superior detectado: 3737235.2929524565
# Number of lines: 3
#
# Processing Vano 48
#
# Reference C_13434482_13434483
# Umbral de corte inferior detectado: 3732141.441366303
# Umbral de corte superior detectado: 3732236.450750622
# Number of lines: 3
#
# Processing Vano 49
#
# Reference C_13434441_13434442
# Umbral de corte inferior detectado: 3736881.1378335357
# Number of lines: 3
#
# Processing Vano 50
#
# Reference C_13412099_13412101
# Umbral de corte inferior detectado: 4011033.0144895134
# Umbral de corte superior detectado: 4011098.178255662
# Number of lines: 3
#
# Processing Vano 51
#
# Reference C_13412103_13412105
# Umbral de corte inferior detectado: -3913062.2240963373
# Umbral de corte superior detectado: -3912980.1953997635
# Number of lines: 3
#
# Processing Vano 52
#
# Reference C_13411885_13411890
#
# Processing Vano 53
#
# Reference C_13412095_13412125
# Umbral de corte inferior detectado: 3905065.733057288
# Umbral de corte superior detectado: 3905134.3725100867
# Number of lines: 3
#
# Processing Vano 54
#
# Reference C_13412123_13412124
# Umbral de corte inferior detectado: -3910760.9893153654
# Umbral de corte superior detectado: -3910656.5822811807
# Number of lines: 6
#
# Processing Vano 55
#
# Reference C_13411667_13411668
#
# Processing Vano 56
#
# Reference C_13411725_13411728
#
# Processing Vano 57
#
# Reference C_13411729_13411730
# Umbral de corte inferior detectado: 4298848.649037011
# Umbral de corte superior detectado: 4298898.620588938
# Number of lines: 3
#
# Processing Vano 58
#
# Reference C_13411715_13411717
# Umbral de corte inferior detectado: -4284764.489855062
# Number of lines: 3
#
# Processing Vano 59
#
# Reference C_13434463_13434464
#
# Processing Vano 60
#
# Reference C_13434457_13434458
# Umbral de corte inferior detectado: -3971573.4345164564
# Umbral de corte superior detectado: -3971418.9563381067
# Number of lines: 3
#
# Processing Vano 61
#
# Reference C_13434445_13434446
# Umbral de corte inferior detectado: 4016848.16463871
# Umbral de corte superior detectado: 4016928.898635343
# Number of lines: 3
#
# Processing Vano 62
#
# Reference C_13434444_13434445
# Umbral de corte superior detectado: 4014893.2397602387
# Number of lines: 3
#
# Processing Vano 63
#
# Reference C_13434442_13434443
# Umbral de corte inferior detectado: -4257070.981341531
# Umbral de corte superior detectado: -4256994.22214446
# Number of lines: 3
#
# Processing Vano 64
#
# Reference C_13412101_13412104
# Umbral de corte inferior detectado: 4023518.179645816
# Number of lines: 3
#
# Processing Vano 65
#
# Reference C_13412078_13412080
# Umbral de corte inferior detectado: -4013233.9801961267
# Umbral de corte superior detectado: -4013150.1909524295
# Number of lines: 3
#
# Processing Vano 66
#
# Reference C_13411820_13411822
# Umbral de corte superior detectado: 3862434.983229182
# Number of lines: 3
#
# Processing Vano 67
#
# Reference C_13412143_13412144
# Umbral de corte superior detectado: -3917017.2993503087
# Number of lines: 3
#
# Processing Vano 68
#
# Reference C_13412138_13412140
# Umbral de corte inferior detectado: 3867080.084290529
# Umbral de corte superior detectado: 3867124.038719784
# Number of lines: 3
#
# Processing Vano 69
#
# Reference C_13411761_13411763
# Umbral de corte inferior detectado: -3861592.526034487
# Umbral de corte superior detectado: -3861512.5069882637
# Number of lines: 3
#
# Processing Vano 70
#
# Reference C_13411668_13411669
# Umbral de corte inferior detectado: 3856275.7798675997
# Umbral de corte superior detectado: 3856349.277834456
# Number of lines: 3
#
# Processing Vano 71
#
# Reference C_13411827_13411830
# Umbral de corte inferior detectado: -3943464.4270201284
# Number of lines: 3
#
# Processing Vano 72
#
# Reference C_13411770_13411771
# Umbral de corte inferior detectado: -1448039.749601314
# Number of lines: 3
#
# Processing Vano 73
#
# Reference C_13434447_13434448
# Umbral de corte inferior detectado: 4183292.3892557574
# Umbral de corte superior detectado: 4183410.2053015414
# Number of lines: 3
#
# Processing Vano 74
#
# Reference C_13434458_13434459
# Umbral de corte inferior detectado: -3944763.083188518
# Umbral de corte superior detectado: -3944667.366518073
# Number of lines: 3
#
# Processing Vano 75
#
# Reference C_13412083_13412084
# Umbral de corte inferior detectado: -4042509.147236964
# Umbral de corte superior detectado: -4042398.7098449925
# Number of lines: 3
#
# Processing Vano 76
#
# Reference C_13412077_13412079
# Umbral de corte inferior detectado: 4140718.7073254115
# Number of lines: 3
#
# Processing Vano 77
#
# Reference C_13412084_13412085
# Umbral de corte inferior detectado: -4133846.5578806247
# Number of lines: 0
#
# Processing Vano 78
#
# Reference C_13412081_13421440
# Umbral de corte inferior detectado: 4042896.175994069
# Umbral de corte superior detectado: 4042957.454687418
# Number of lines: 3
#
# Processing Vano 79
#
# Reference C_13412080_13412099
# Umbral de corte inferior detectado: -4012877.978915671
# Umbral de corte superior detectado: -4012798.323569059
# Number of lines: 3
#
# Processing Vano 80
#
# Reference C_13412078_13412079
# Umbral de corte inferior detectado: 4006235.1498128874
# Umbral de corte superior detectado: 4006312.9619961004
# Number of lines: 3
#
# Processing Vano 81
#
# Reference C_13411824_13411826
# Umbral de corte inferior detectado: -3977178.6397466976
# Umbral de corte superior detectado: -3977167.7525677886
# Number of lines: 3
#
# Processing Vano 82
#
# Reference C_13411659_13411681
# Umbral de corte inferior detectado: 3858929.508207916
# Umbral de corte superior detectado: 3859013.7474579136
# Number of lines: 3
#
# Processing Vano 83
#
# Reference C_13412095_13412096
# Umbral de corte inferior detectado: -3912509.186760377
# Umbral de corte superior detectado: -3912482.342019812
# Number of lines: 3
#
# Processing Vano 84
#
# Reference C_13411669_13411672
# Umbral de corte inferior detectado: -3865335.6304294798
# Umbral de corte superior detectado: -3865292.0161947
# Number of lines: 3
#
# Processing Vano 85
#
# Reference C_13412125_13412126
# Umbral de corte superior detectado: -3904246.412953089
# Number of lines: 3
#
# Processing Vano 86
#
# Reference C_13412114_13412115
# Umbral de corte inferior detectado: 2808496.1374934088
# Umbral de corte superior detectado: 2808664.1258283183
# Number of lines: 3
#
# Processing Vano 87
#
# Reference C_13411711_13411713
# Umbral de corte inferior detectado: 1487843.5822708542
# Umbral de corte superior detectado: 1487984.2340876258
# Number of lines: 3
#
# Processing Vano 88
#
# Reference C_13411711_13411717
# Umbral de corte inferior detectado: 3037062.1993873166
# Umbral de corte superior detectado: 3037167.0213898486
# Number of lines: 3
#
# Processing Vano 89
#
# Reference C_13411829_13411830
#
# Processing Vano 90
#
# Reference C_13412039_13412041
# Umbral de corte inferior detectado: -4037311.4566695965
# Umbral de corte superior detectado: -4037253.213710172
# Number of lines: 3
#
# Processing Vano 91
#
# Reference C_13434454_13434455
# Umbral de corte inferior detectado: 3735537.177968356
# Umbral de corte superior detectado: 3735647.065497612
# Number of lines: 3
#
# Processing Vano 92
#
# Reference C_13434448_13434449
# Umbral de corte inferior detectado: -4181588.3658406534
# Umbral de corte superior detectado: -4181527.6593655366
# Number of lines: 3
#
# Processing Vano 93
#
# Reference C_13434440_13434484
# Umbral de corte inferior detectado: 3736338.6751696393
# Umbral de corte superior detectado: 3736443.3285325128
# Number of lines: 3
#
# Processing Vano 94
#
# Reference C_13434451_13434452
# Umbral de corte inferior detectado: -4258069.190964897
# Umbral de corte superior detectado: -4257982.003581365
# Number of lines: 3
#
# Processing Vano 95
#
# Reference C_13412081_13412082
# Umbral de corte inferior detectado: 4037213.503872115
# Umbral de corte superior detectado: 4037318.550741935
# Number of lines: 3
#
# Processing Vano 96
#
# Reference C_13412051_13412064
# Umbral de corte superior detectado: 3846220.750318847
# Number of lines: 3
#
# Processing Vano 97
#
# Reference C_13411665_13411697
# Umbral de corte inferior detectado: -3865460.253591858
# Umbral de corte superior detectado: -3865375.2173659564
# Number of lines: 3
#
# Processing Vano 98
#
# Reference C_13412126_13412127
# Umbral de corte superior detectado: 3913067.1801109826
# Number of lines: 3
#
# Processing Vano 99
#
# Reference C_13412139_13412142
# Umbral de corte inferior detectado: 3866312.3663636274
# Umbral de corte superior detectado: 3866360.7682526316
# Number of lines: 3
#
# Processing Vano 100
#
# Reference C_13412122_13412123
# Umbral de corte superior detectado: -3911204.6028943206
# Number of lines: 3
#
# Processing Vano 101
#
# Reference C_13411675_13411678
# Umbral de corte inferior detectado: -3864463.645493815
# Umbral de corte superior detectado: -3864420.050965151
# Number of lines: 3
#
# Processing Vano 102
#
# Reference C_13411678_13411681
# Umbral de corte inferior detectado: 3864178.0408014115
# Umbral de corte superior detectado: 3864208.6874276674
# Number of lines: 3
#
# Processing Vano 103
#
# Reference C_13412116_13412117
# Umbral de corte inferior detectado: -2803658.951073761
# Umbral de corte superior detectado: -2803473.3014837904
# Number of lines: 3
#
# Processing Vano 104
#
# Reference C_13411888_13412152
# Umbral de corte superior detectado: -2754411.209369569
# Number of lines: 3
#
# Processing Vano 105
#
# Reference C_13411713_13411774
# Umbral de corte inferior detectado: -1526955.7341852714
# Number of lines: 3
#
# Processing Vano 106
#
# Reference C_13411767_13411776
# Umbral de corte superior detectado: 1445349.1193389655
# Number of lines: 3
#
# Processing Vano 107
#
# Reference C_13434483_13434484
# Umbral de corte inferior detectado: 3734505.802123469
# Umbral de corte superior detectado: 3734577.790324101
# Number of lines: 3
#
# Processing Vano 108
#
# Reference C_13434446_13434447
# Umbral de corte inferior detectado: 4022819.3845308824
# Umbral de corte superior detectado: 4022878.575023149
# Number of lines: 3
#
# Processing Vano 109
#
# Reference C_13434449_13434451
# Umbral de corte superior detectado: 4187165.9884253875
# Number of lines: 3
#
# Processing Vano 110
#
# Reference C_13412104_13412105
# Umbral de corte inferior detectado: 3891729.3317728112
# Umbral de corte superior detectado: 3891785.73354123
# Number of lines: 3
#
# Processing Vano 111
#
# Reference C_13411888_13411891
# Umbral de corte superior detectado: -4162491.6207617633
# Number of lines: 3
#
# Processing Vano 112
#
# Reference C_13411772_13411889
#
# Processing Vano 113
#
# Reference C_13412051_13412052
# Umbral de corte inferior detectado: 3848552.5694688773
# Umbral de corte superior detectado: 3848582.467112144
# Number of lines: 3
#
# Processing Vano 114
#
# Reference C_13412064_13412065
# Umbral de corte inferior detectado: 3866954.593071849
# Number of lines: 3
#
# Processing Vano 115
#
# Reference C_13412065_13412066
# Umbral de corte inferior detectado: -3857215.806203604
# Number of lines: 3
#
# Processing Vano 116
#
# Reference C_13411672_13411675
# Umbral de corte superior detectado: 3863521.2178257643
# Number of lines: 3
#
# Processing Vano 117
#
# Reference C_13411761_13411826
# Umbral de corte inferior detectado: 3866299.177250024
# Number of lines: 3
#
# Processing Vano 118
#
# Reference C_13411697_13411763
# Umbral de corte inferior detectado: -3864604.174405791
# Umbral de corte superior detectado: -3864544.1258537965
# Number of lines: 3
#
# Processing Vano 119
#
# Reference C_13412098_13412103
# Umbral de corte inferior detectado: 3910895.1067681233
# Umbral de corte superior detectado: 3910969.671774069
# Number of lines: 3
#
# Processing Vano 120
#
# Reference C_13412121_13412122
# Umbral de corte inferior detectado: 3907373.2046742
# Number of lines: 3
#
# Processing Vano 121
#
# Reference C_13412148_13412152
# Umbral de corte inferior detectado: 2818277.3661333434
# Umbral de corte superior detectado: 2818478.8573532784
# Number of lines: 3
#
# Processing Vano 122
#
# Reference C_13411715_13411722
# Umbral de corte inferior detectado: 4275699.827672516
# Umbral de corte superior detectado: 4275768.754801468
# Number of lines: 3
#
# Processing Vano 123
#
# Reference C_13411720_13411722
# Umbral de corte inferior detectado: -4274630.00482435
# Umbral de corte superior detectado: -4274561.144429718
# Number of lines: 3
#
# Processing Vano 124
#
# Reference C_13411824_13411828
# Umbral de corte inferior detectado: -3948195.7722444166
# Umbral de corte superior detectado: -3948051.6932727066
# Number of lines: 3
#
# Processing Vano 125
#
# Reference C_13411775_13411776
# Umbral de corte inferior detectado: -1452944.624091719
# Umbral de corte superior detectado: -1452792.4432929119
# Number of lines: 0
#
# Processing Vano 126
#
# Reference C_13434480_13434481
#
# Processing Vano 127
#
# Reference C_13434455_13434456
# Umbral de corte inferior detectado: 3732000.1968580177
# Umbral de corte superior detectado: 3732137.8999209916
# Number of lines: 3
#
# Processing Vano 128
#
# Reference C_13412082_13412083
# Umbral de corte inferior detectado: -4038089.824219702
# Umbral de corte superior detectado: -4038032.931456473
# Number of lines: 3

# %% [markdown]
# Recogida de ajustes y eliminación de outliers en parámetros

# %%
import os
import json 
import numpy as np

pathdata2 = os.getcwd()+'/'+[el for el in os.listdir(os.getcwd()) if 'REG_resultado' in el][0]

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)

df_reg=data_catenaryparameters_to_df(data)


pathdata2 = os.getcwd()+'/'+[el for el in os.listdir(os.getcwd()) if 'VDI_resultado' in el][0]

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)

df_vdi=data_catenaryparameters_to_df(data)


pathdata2 = os.getcwd()+'/'+[el for el in os.listdir(os.getcwd()) if 'XIN_resultado' in el][0]

with open(pathdata2, 'r') as archivo:
    data = json.load(archivo)

df_xin=data_catenaryparameters_to_df(data)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
df_reg.shape
# Out:
# (155, 4)

# %%
df_vdi.shape
# Out:
# (129, 4)

# %%
df_xin.shape
# Out:
# (163, 4)

# %%
df_reg=df_reg.dropna()
df_reg=df_reg.loc[df_reg['id'].isin(reg.to_list())]
df_vdi=df_vdi.dropna()
df_vdi=df_vdi.loc[df_vdi['id'].isin(vdi.to_list())]
df_xin=df_xin.dropna()
df_xin=df_xin.loc[df_xin['id'].isin(xin.to_list())]

# %%
df_reg.shape
# Out:
# (65, 4)

# %%
df_vdi.shape
# Out:
# (86, 5)

# %%
df_xin.shape
# Out:
# (121, 4)

# %%
df_reg=pretreatment_linegroup_from_json(df_reg)
df_vdi=pretreatment_linegroup_from_json(df_vdi)
df_xin=pretreatment_linegroup_from_json(df_xin)

# %%
df_reg.shape
# Out:
# (45, 5)

# %%
df_vdi.shape
# Out:
# (86, 5)

# %%
df_xin.shape
# Out:
# (103, 5)
